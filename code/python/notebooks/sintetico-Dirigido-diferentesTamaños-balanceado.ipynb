# %%
# !pip install networkx
# Out:
# Requirement already satisfied: networkx in /usr/local/lib/python3.8/dist-packages (3.1)
# WARNING: You are using pip version 20.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      |████████████████████████████████| 293 kB 928 kB/s eta 0:00:01
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /usr/local/lib/python3.8/dist-packages (from seaborn) (3.6.2)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.8/dist-packages (from seaborn) (1.5.3)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /usr/local/lib/python3.8/dist-packages (from seaborn) (1.23.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.3.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.14.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.12.2
# WARNING: You are using pip version 20.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import networkx as nx

import os
import numpy as np
import matplotlib.pyplot as plt
import gc

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

from spektral.data import Dataset, Graph
from spektral.layers import GraphSageConv
from spektral.utils import normalized_adjacency
from spektral.models.gcn import GCN 
from spektral.datasets.utils import DATASET_FOLDER

from scipy import sparse
from scipy.special import softmax

from sklearn.model_selection import train_test_split

# %%
def plot_graph_dir(G, communities=None):
    pos = nx.spring_layout(G, seed=42)
    
    if communities is not None:
        # Assign colors to nodes based on their communities
        colors = ['orange' if community == 0 else 'skyblue' for community in communities]
    else:
        colors = 'red'

    nx.draw_networkx(G, pos, arrows=True, node_color=colors, with_labels=True)
    plt.show()

# %% [markdown]
# # Caso 1: dirigido, diferentes tamaños, balanceado, clases separadas
#
# No dirigido, i.e. matriz de adyacencia simétrica
#
# Tamaños (número de nodos): 25, 50, 100, 200, 400, 800, 1600, 3200, 6400, 12800
#
# Clases "separadas"

# %%
class synthetic_Dir_diffSize_balanced_clasesSep(Dataset):
    
    def __init__(self, **kwargs):
        super().__init__(**kwargs)

    @property
    def path(self):
        return os.path.join(DATASET_FOLDER, "syntheticGraphs", self.__class__.__name__)
    
    def download(self):
        os.makedirs(self.path)
        
        def generate_synthetic_graph_csbm(n_nodes, n_communities, n_features, edge_prob_matrix, node_feature_means,\
                                  semilla, indice, feature_cov_matrix=None):
            # Assign nodes to communities
            np.random.seed(semilla*(indice+1))
            communities = np.random.randint(0, n_communities, n_nodes)

            # Generate node features
            if feature_cov_matrix is None:
                feature_cov_matrix = np.eye(n_features)
            features = np.zeros((n_nodes, n_features))
            for k in range(n_communities):
                nodes_in_community = np.where(communities == k)[0]
                features[nodes_in_community] = np.random.multivariate_normal(node_feature_means[k], feature_cov_matrix,\
                                                                             len(nodes_in_community))

            # Compute community membership probabilities based on node features
            community_membership_probs = softmax(features @ node_feature_means.T, axis=1)

            # Generate edges based on community membership probabilities
            adjacency_matrix = np.zeros((n_nodes, n_nodes))
            for i in range(n_nodes):
                for j in range(n_nodes):
                    if i == j:
                        continue
                    community_i = communities[i]
                    community_j = communities[j]
                    edge_prob = edge_prob_matrix[community_i, community_j] * community_membership_probs[i, community_j] * community_membership_probs[j, community_i]
                    adjacency_matrix[i, j] = np.random.binomial(1, edge_prob)

            labels = tf.keras.utils.to_categorical(communities)
            adjacency_matrix = sparse.csr_matrix(adjacency_matrix)
            return Graph(x=features, a=adjacency_matrix, y=labels)

        
        n_graphs = 10
        n_nodes = [25, 50, 100, 200, 400, 800, 1600, 3200, 6400, 12800]
        n_features = 2
        n_classes = 2
        # Probability matrix for edges between communities
        edge_prob_matrix = np.array([
                                        [0.8, 0.2],
                                        [0.3, 0.7]
                                    ])
        # Node feature means for each community
        node_feature_means = np.array([
                                        [2, 1], #, 0, 0, 0],
                                        [1, 2] #, 0, 0, 0]
                                    ])
        
        semillas = [123, 234, 345, 456, 567, 678, 789, 321, 654, 987]
        
        # Bien separadas las clases:
        graphs1 = [generate_synthetic_graph_csbm(n_nodes[i], n_classes, n_features, edge_prob_matrix, node_feature_means, semillas[i], 0, feature_cov_matrix=None) for i in range(n_graphs)]
        for j in range(10):
            filename = os.path.join(self.path, f'graph_Dir_{n_nodes[j]}nodes_balanced_clasesSep_0{j}.npz')
            np.savez(filename, x=graphs1[j].x, a=graphs1[j].a, y=graphs1[j].y)

        # Free memory
        del graphs1
        gc.collect()


    def read(self):
        # We must return a list of Graph objects
        output = []
        
        n_nodes = [25, 50, 100, 200, 400, 800, 1600, 3200, 6400, 12800]
        
        for j in range(10):
            data1 = np.load(os.path.join(self.path, f'graph_Dir_{n_nodes[j]}nodes_balanced_clasesSep_0{j}.npz'), allow_pickle=True)
            output.append(
                Graph(x=data1['x'], a=data1['a'][()], y=data1['y']) # también puede ser a=data['a'].item()
            )

        return output

# %%
dataset1 = synthetic_Dir_diffSize_balanced_clasesSep()

# %%
for G in dataset1:
    nxG = nx.from_numpy_array(G.a,create_using=nx.DiGraph)
    labels = np.argmax(G.y,axis=1)
    plot_graph_dir(nxG,labels)
# Out:
# KeyboardInterruptTraceback (most recent call last)
# Cell In [5], line 4
#       2 nxG = nx.from_numpy_array(G.a,create_using=nx.DiGraph)
#       3 labels = np.argmax(G.y,axis=1)
# ----> 4 plot_graph_dir(nxG,labels)
#
# Cell In [2], line 10, in plot_graph_dir(G, communities)
#       7 else:
#       8     colors = 'red'
# ---> 10 nx.draw_networkx(G, pos, arrows=True, node_color=colors, with_labels=True)
#      11 plt.show()
#
# File /usr/local/lib/python3.8/dist-packages/networkx/drawing/nx_pylab.py:304, in draw_networkx(G, pos, arrows, with_labels, **kwds)
#     301     pos = nx.drawing.spring_layout(G)  # default to spring layout
#     303 draw_networkx_nodes(G, pos, **node_kwds)
# --> 304 draw_networkx_edges(G, pos, arrows=arrows, **edge_kwds)
#     305 if with_labels:
#     306     draw_networkx_labels(G, pos, **label_kwds)
#
# File /usr/local/lib/python3.8/dist-packages/networkx/drawing/nx_pylab.py:908, in draw_networkx_edges(G, pos, edgelist, width, edge_color, style, alpha, arrowstyle, arrowsize, edge_cmap, edge_vmin, edge_vmax, ax, arrows, label, node_size, nodelist, node_shape, connectionstyle, min_source_margin, min_target_margin)
#     906 else:
#     907     fancy_edges_indices = range(len(edgelist))
# --> 908     edge_viz_obj = _draw_networkx_edges_fancy_arrow_patch()
#     910 # update view after drawing
#     911 padx, pady = 0.05 * w, 0.05 * h
#
# File /usr/local/lib/python3.8/dist-packages/networkx/drawing/nx_pylab.py:882, in draw_networkx_edges.<locals>._draw_networkx_edges_fancy_arrow_patch()
#     867     arrow = mpl.patches.FancyArrowPatch(
#     868         (x1, y1),
#     869         (x2, y2),
#    (...)
#     878         zorder=1,
#     879     )  # arrows go behind nodes
#     881     arrow_collection.append(arrow)
# --> 882     ax.add_patch(arrow)
#     884 return arrow_collection
#
# File /usr/local/lib/python3.8/dist-packages/matplotlib/axes/_base.py:2415, in _AxesBase.add_patch(self, p)
#    2413 if p.get_clip_path() is None:
#    2414     p.set_clip_path(self.patch)
# -> 2415 self._update_patch_limits(p)
#    2416 self._children.append(p)
#    2417 p._remove_method = self._children.remove
#
# File /usr/local/lib/python3.8/dist-packages/matplotlib/axes/_base.py:2433, in _AxesBase._update_patch_limits(self, patch)
#    2430 if (isinstance(patch, mpatches.Rectangle) and
#    2431         ((not patch.get_width()) and (not patch.get_height()))):
#    2432     return
# -> 2433 p = patch.get_path()
#    2434 # Get all vertices on the path
#    2435 # Loop through each segment to get extrema for Bezier curve sections
#    2436 vertices = []
#
# File /usr/local/lib/python3.8/dist-packages/matplotlib/patches.py:4417, in FancyArrowPatch.get_path(self)
#    4414 """Return the path of the arrow in the data coordinates."""
#    4415 # The path is generated in display coordinates, then converted back to
#    4416 # data coordinates.
# -> 4417 _path, fillable = self._get_path_in_displaycoord()
#    4418 if np.iterable(fillable):
#    4419     _path = Path.make_compound_path(*_path)
#
# File /usr/local/lib/python3.8/dist-packages/matplotlib/patches.py:4439, in FancyArrowPatch._get_path_in_displaycoord(self)
#    4436 else:
#    4437     _path = self.get_transform().transform_path(self._path_original)
# -> 4439 _path, fillable = self.get_arrowstyle()(
#    4440     _path,
#    4441     self.get_mutation_scale() * dpi_cor,
#    4442     self.get_linewidth() * dpi_cor,
#    4443     self.get_mutation_aspect())
#    4445 return _path, fillable
#
# File /usr/local/lib/python3.8/dist-packages/matplotlib/patches.py:3192, in ArrowStyle._Base.__call__(self, path, mutation_size, linewidth, aspect_ratio)
#    3190 path_shrunk = Path(vertices, path.codes)
#    3191 # call transmute method with squeezed height.
# -> 3192 path_mutated, fillable = self.transmute(path_shrunk,
#    3193                                         mutation_size,
#    3194                                         linewidth)
#    3195 if np.iterable(fillable):
#    3196     # Restore the height
#    3197     path_list = [Path(p.vertices * [1, aspect_ratio], p.codes)
#    3198                  for p in path_mutated]
#
# File /usr/local/lib/python3.8/dist-packages/matplotlib/patches.py:3422, in ArrowStyle._Curve.transmute(self, path, mutation_size, linewidth)
#    3413 verticesB, codesB, ddxB, ddyB = (
#    3414     self._get_arrow_wedge(x2, y2, x3, y3,
#    3415                           head_dist, cos_t, sin_t, linewidth)
#    3416     if has_end_arrow
#    3417     else ([], [], 0, 0)
#    3418 )
#    3420 # This simple code will not work if ddx, ddy is greater than the
#    3421 # separation between vertices.
# -> 3422 _path = [Path(np.concatenate([[(x0 + ddxA, y0 + ddyA)],
#    3423                               path.vertices[1:-1],
#    3424                               [(x3 + ddxB, y3 + ddyB)]]),
#    3425               path.codes)]
#    3426 _fillable = [False]
#    3428 if has_begin_arrow:
#
# File <__array_function__ internals>:180, in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# # Caso 2: dirigido, diferentes tamaños, balanceado, clases más juntas
#
# No dirigido, i.e. matriz de adyacencia simétrica
#
# Tamaños (número de nodos): 25, 50, 100, 200, 400, 800, 1600, 3200, 6400, 12800
#
# Clases "más juntas"

# %%
class synthetic_Dir_diffSize_balanced_clasesJunt(Dataset):
    
    def __init__(self, **kwargs):
        super().__init__(**kwargs)

    @property
    def path(self):
        return os.path.join(DATASET_FOLDER, "syntheticGraphs", self.__class__.__name__)
    
    def download(self):
        os.makedirs(self.path)
        
        def generate_synthetic_graph_csbm(n_nodes, n_communities, n_features, edge_prob_matrix, node_feature_means,\
                                  semilla, indice, feature_cov_matrix=None):
            # Assign nodes to communities
            np.random.seed(semilla*(indice+1))
            communities = np.random.randint(0, n_communities, n_nodes)

            # Generate node features
            if feature_cov_matrix is None:
                feature_cov_matrix = np.eye(n_features)
            features = np.zeros((n_nodes, n_features))
            for k in range(n_communities):
                nodes_in_community = np.where(communities == k)[0]
                features[nodes_in_community] = np.random.multivariate_normal(node_feature_means[k], feature_cov_matrix,\
                                                                             len(nodes_in_community))

            # Compute community membership probabilities based on node features
            community_membership_probs = softmax(features @ node_feature_means.T, axis=1)

            # Generate edges based on community membership probabilities
            adjacency_matrix = np.zeros((n_nodes, n_nodes))
            for i in range(n_nodes):
                for j in range(n_nodes):
                    if i == j:
                        continue
                    community_i = communities[i]
                    community_j = communities[j]
                    edge_prob = edge_prob_matrix[community_i, community_j] * community_membership_probs[i, community_j] * community_membership_probs[j, community_i]
                    adjacency_matrix[i, j] = np.random.binomial(1, edge_prob)

            labels = tf.keras.utils.to_categorical(communities)
            adjacency_matrix = sparse.csr_matrix(adjacency_matrix)
            return Graph(x=features, a=adjacency_matrix, y=labels)

        
        n_graphs = 10
        n_nodes = [25, 50, 100, 200, 400, 800, 1600, 3200, 6400, 12800]
        n_features = 2
        n_classes = 2
        # Probability matrix for edges between communities
        edge_prob_matrix = np.array([
                                    [0.5, 0.5],
                                    [0.5, 0.5]
                            ])
        # Node feature means for each community
        node_feature_means = np.array([
                                        [2, 1], #, 0, 0, 0],
                                        [1, 2] #, 0, 0, 0]
                                    ])
        
        semillas = [123, 234, 345, 456, 567, 678, 789, 321, 654, 987]
        
        # Clases un poco más juntas:
        graphs2 = [generate_synthetic_graph_csbm(n_nodes[i], n_classes, n_features, edge_prob_matrix, node_feature_means, semillas[i], 1, feature_cov_matrix=None) for i in range(n_graphs)]
        for j in range(10):
            filename = os.path.join(self.path, f'graph_Dir_{n_nodes[j]}nodes_balanced_clasesJunt_1{j}.npz')
            np.savez(filename, x=graphs2[j].x, a=graphs2[j].a, y=graphs2[j].y)

        # Free memory
        del graphs2
        gc.collect()


    def read(self):
        # We must return a list of Graph objects
        output = []
        
        n_nodes = [25, 50, 100, 200, 400, 800, 1600, 3200, 6400, 12800]
        
        for j in range(10):
            data2 = np.load(os.path.join(self.path, f'graph_Dir_{n_nodes[j]}nodes_balanced_clasesJunt_1{j}.npz'), allow_pickle=True)
            output.append(
                Graph(x=data2['x'], a=data2['a'][()], y=data2['y']) # también puede ser a=data['a'].item()
            )

        return output

# %%
dataset2 = synthetic_Dir_diffSize_balanced_clasesJunt()

# %%
for G in dataset2:
    nxG = nx.from_numpy_array(G.a,create_using=nx.DiGraph)
    labels = np.argmax(G.y,axis=1)
    plot_graph_dir(nxG,labels)
# Out:
# KeyboardInterruptTraceback (most recent call last)
# Cell In [13], line 4
#       2 nxG = nx.from_numpy_array(G.a,create_using=nx.DiGraph)
#       3 labels = np.argmax(G.y,axis=1)
# ----> 4 plot_graph_dir(nxG,labels)
#
# Cell In [2], line 10, in plot_graph_dir(G, communities)
#       7 else:
#       8     colors = 'red'
# ---> 10 nx.draw_networkx(G, pos, arrows=True, node_color=colors, with_labels=True)
#      11 plt.show()
#
# File /usr/local/lib/python3.8/dist-packages/networkx/drawing/nx_pylab.py:304, in draw_networkx(G, pos, arrows, with_labels, **kwds)
#     301     pos = nx.drawing.spring_layout(G)  # default to spring layout
#     303 draw_networkx_nodes(G, pos, **node_kwds)
# --> 304 draw_networkx_edges(G, pos, arrows=arrows, **edge_kwds)
#     305 if with_labels:
#     306     draw_networkx_labels(G, pos, **label_kwds)
#
# File /usr/local/lib/python3.8/dist-packages/networkx/drawing/nx_pylab.py:908, in draw_networkx_edges(G, pos, edgelist, width, edge_color, style, alpha, arrowstyle, arrowsize, edge_cmap, edge_vmin, edge_vmax, ax, arrows, label, node_size, nodelist, node_shape, connectionstyle, min_source_margin, min_target_margin)
#     906 else:
#     907     fancy_edges_indices = range(len(edgelist))
# --> 908     edge_viz_obj = _draw_networkx_edges_fancy_arrow_patch()
#     910 # update view after drawing
#     911 padx, pady = 0.05 * w, 0.05 * h
#
# File /usr/local/lib/python3.8/dist-packages/networkx/drawing/nx_pylab.py:882, in draw_networkx_edges.<locals>._draw_networkx_edges_fancy_arrow_patch()
#     867     arrow = mpl.patches.FancyArrowPatch(
#     868         (x1, y1),
#     869         (x2, y2),
#    (...)
#     878         zorder=1,
#     879     )  # arrows go behind nodes
#     881     arrow_collection.append(arrow)
# --> 882     ax.add_patch(arrow)
#     884 return arrow_collection
#
# File /usr/local/lib/python3.8/dist-packages/matplotlib/axes/_base.py:2412, in _AxesBase.add_patch(self, p)
#    2408 """
#    2409 Add a `.Patch` to the Axes; return the patch.
#    2410 """
#    2411 self._deprecate_noninstance('add_patch', mpatches.Patch, p=p)
# -> 2412 self._set_artist_props(p)
#    2413 if p.get_clip_path() is None:
#    2414     p.set_clip_path(self.patch)
#
# File /usr/local/lib/python3.8/dist-packages/matplotlib/axes/_base.py:1140, in _AxesBase._set_artist_props(self, a)
#    1138 a.set_figure(self.figure)
#    1139 if not a.is_transform_set():
# -> 1140     a.set_transform(self.transData)
#    1142 a.axes = self
#    1143 if a.get_mouseover():
#
# File /usr/local/lib/python3.8/dist-packages/matplotlib/artist.py:419, in Artist.set_transform(self, t)
#     417 self._transformSet = True
#     418 self.pchanged()
# --> 419 self.stale = True
#
# File /usr/local/lib/python3.8/dist-packages/matplotlib/artist.py:291, in Artist.stale(self, val)
#     289 @stale.setter
#     290 def stale(self, val):
# --> 291     self._stale = val
#     293     # if the artist is animated it does not take normal part in the
#     294     # draw stack and is not expected to be drawn as part of the normal
#     295     # draw loop (when not saving) so do not propagate this change
#     296     if self.get_animated():
#
# KeyboardInterrupt:

# %% [markdown]
# # Caso 3: dirigido, diferentes tamaños, balanceado, clases mezcladas
#
# No dirigido, i.e. matriz de adyacencia simétrica
#
# Tamaños: 25, 50, 100, 200, 400, 800, 1600, 3200, 6400, 12800
#
# Clases "mezcladas" (a juzgar por la representación gráfica)

# %%
class synthetic_Dir_diffSize_balanced_clasesMezcl(Dataset):
    
    def __init__(self, **kwargs):
        super().__init__(**kwargs)

    @property
    def path(self):
        return os.path.join(DATASET_FOLDER, "syntheticGraphs", self.__class__.__name__)
    
    def download(self):
        os.makedirs(self.path)
        
        def generate_synthetic_graph_csbm(n_nodes, n_communities, n_features, edge_prob_matrix, node_feature_means,\
                                  semilla, indice, feature_cov_matrix=None):
            # Assign nodes to communities
            np.random.seed(semilla*(indice+1))
            communities = np.random.randint(0, n_communities, n_nodes)

            # Generate node features
            if feature_cov_matrix is None:
                feature_cov_matrix = np.eye(n_features)
            features = np.zeros((n_nodes, n_features))
            for k in range(n_communities):
                nodes_in_community = np.where(communities == k)[0]
                features[nodes_in_community] = np.random.multivariate_normal(node_feature_means[k], feature_cov_matrix,\
                                                                             len(nodes_in_community))

            # Compute community membership probabilities based on node features
            community_membership_probs = softmax(features @ node_feature_means.T, axis=1)

            # Generate edges based on community membership probabilities
            adjacency_matrix = np.zeros((n_nodes, n_nodes))
            for i in range(n_nodes):
                for j in range(n_nodes):
                    if i == j:
                        continue
                    community_i = communities[i]
                    community_j = communities[j]
                    edge_prob = edge_prob_matrix[community_i, community_j] * community_membership_probs[i, community_j] * community_membership_probs[j, community_i]
                    adjacency_matrix[i, j] = np.random.binomial(1, edge_prob)

            labels = tf.keras.utils.to_categorical(communities)
            adjacency_matrix = sparse.csr_matrix(adjacency_matrix)
            return Graph(x=features, a=adjacency_matrix, y=labels)

        
        n_graphs = 10
        n_nodes = [25, 50, 100, 200, 400, 800, 1600, 3200, 6400, 12800]
        n_features = 2
        n_classes = 2
        # Probability matrix for edges between communities
        edge_prob_matrix = np.array([
                                    [0.5, 0.5],
                                    [0.5, 0.5]
                            ])
        # Node feature means for each community
        node_feature_means = np.array([
                                        [1, 1], #, 0, 0, 0],
                                        [1, 1] #, 0, 0, 0]
                                    ])
        
        semillas = [123, 234, 345, 456, 567, 678, 789, 321, 654, 987]
        
        # Clases completamente mezcladas:
        graphs3 = [generate_synthetic_graph_csbm(n_nodes[i], n_classes, n_features, edge_prob_matrix, node_feature_means, semillas[i], 2, feature_cov_matrix=None) for i in range(n_graphs)]
        for j in range(10):
            filename = os.path.join(self.path, f'graph_Dir_{n_nodes[j]}nodes_balanced_clasesMezcl_2{j}.npz')
            np.savez(filename, x=graphs3[j].x, a=graphs3[j].a, y=graphs3[j].y)
            
        # Free memory
        del graphs3
        gc.collect()


    def read(self):
        # We must return a list of Graph objects
        output = []

        n_nodes = [25, 50, 100, 200, 400, 800, 1600, 3200, 6400, 12800]
        
        for j in range(10):
            data3 = np.load(os.path.join(self.path, f'graph_Dir_{n_nodes[j]}nodes_balanced_clasesMezcl_2{j}.npz'), allow_pickle=True)
            output.append(
                Graph(x=data3['x'], a=data3['a'][()], y=data3['y']) # también puede ser a=data['a'].item()
            )

        return output

# %%
dataset3 = synthetic_Dir_diffSize_balanced_clasesMezcl()

# %%
for G in dataset3:
    nxG = nx.from_numpy_array(G.a,create_using=nx.DiGraph)
    labels = np.argmax(G.y,axis=1)
    plot_graph_dir(nxG,labels)
# Out:
# KeyboardInterruptTraceback (most recent call last)
# Cell In [22], line 4
#       2 nxG = nx.from_numpy_array(G.a,create_using=nx.DiGraph)
#       3 labels = np.argmax(G.y,axis=1)
# ----> 4 plot_graph_dir(nxG,labels)
#
# Cell In [2], line 10, in plot_graph_dir(G, communities)
#       7 else:
#       8     colors = 'red'
# ---> 10 nx.draw_networkx(G, pos, arrows=True, node_color=colors, with_labels=True)
#      11 plt.show()
#
# File /usr/local/lib/python3.8/dist-packages/networkx/drawing/nx_pylab.py:304, in draw_networkx(G, pos, arrows, with_labels, **kwds)
#     301     pos = nx.drawing.spring_layout(G)  # default to spring layout
#     303 draw_networkx_nodes(G, pos, **node_kwds)
# --> 304 draw_networkx_edges(G, pos, arrows=arrows, **edge_kwds)
#     305 if with_labels:
#     306     draw_networkx_labels(G, pos, **label_kwds)
#
# File /usr/local/lib/python3.8/dist-packages/networkx/drawing/nx_pylab.py:908, in draw_networkx_edges(G, pos, edgelist, width, edge_color, style, alpha, arrowstyle, arrowsize, edge_cmap, edge_vmin, edge_vmax, ax, arrows, label, node_size, nodelist, node_shape, connectionstyle, min_source_margin, min_target_margin)
#     906 else:
#     907     fancy_edges_indices = range(len(edgelist))
# --> 908     edge_viz_obj = _draw_networkx_edges_fancy_arrow_patch()
#     910 # update view after drawing
#     911 padx, pady = 0.05 * w, 0.05 * h
#
# File /usr/local/lib/python3.8/dist-packages/networkx/drawing/nx_pylab.py:882, in draw_networkx_edges.<locals>._draw_networkx_edges_fancy_arrow_patch()
#     867     arrow = mpl.patches.FancyArrowPatch(
#     868         (x1, y1),
#     869         (x2, y2),
#    (...)
#     878         zorder=1,
#     879     )  # arrows go behind nodes
#     881     arrow_collection.append(arrow)
# --> 882     ax.add_patch(arrow)
#     884 return arrow_collection
#
# File /usr/local/lib/python3.8/dist-packages/matplotlib/axes/_base.py:2415, in _AxesBase.add_patch(self, p)
#    2413 if p.get_clip_path() is None:
#    2414     p.set_clip_path(self.patch)
# -> 2415 self._update_patch_limits(p)
#    2416 self._children.append(p)
#    2417 p._remove_method = self._children.remove
#
# File /usr/local/lib/python3.8/dist-packages/matplotlib/axes/_base.py:2433, in _AxesBase._update_patch_limits(self, patch)
#    2430 if (isinstance(patch, mpatches.Rectangle) and
#    2431         ((not patch.get_width()) and (not patch.get_height()))):
#    2432     return
# -> 2433 p = patch.get_path()
#    2434 # Get all vertices on the path
#    2435 # Loop through each segment to get extrema for Bezier curve sections
#    2436 vertices = []
#
# File /usr/local/lib/python3.8/dist-packages/matplotlib/patches.py:4417, in FancyArrowPatch.get_path(self)
#    4414 """Return the path of the arrow in the data coordinates."""
#    4415 # The path is generated in display coordinates, then converted back to
#    4416 # data coordinates.
# -> 4417 _path, fillable = self._get_path_in_displaycoord()
#    4418 if np.iterable(fillable):
#    4419     _path = Path.make_compound_path(*_path)
#
# File /usr/local/lib/python3.8/dist-packages/matplotlib/patches.py:4430, in FancyArrowPatch._get_path_in_displaycoord(self)
#    4428     posB = self._convert_xy_units(self._posA_posB[1])
#    4429     (posA, posB) = self.get_transform().transform((posA, posB))
# -> 4430     _path = self.get_connectionstyle()(posA, posB,
#    4431                                        patchA=self.patchA,
#    4432                                        patchB=self.patchB,
#    4433                                        shrinkA=self.shrinkA * dpi_cor,
#    4434                                        shrinkB=self.shrinkB * dpi_cor
#    4435                                        )
#    4436 else:
#    4437     _path = self.get_transform().transform_path(self._path_original)
#
# File /usr/local/lib/python3.8/dist-packages/networkx/drawing/nx_pylab.py:809, in draw_networkx_edges.<locals>._draw_networkx_edges_fancy_arrow_patch.<locals>._connectionstyle(posA, posB, *args, **kwargs)
#     806     ret = mpl.path.Path(ax.transData.transform(path), [1, 4, 4, 4, 4, 4, 4])
#     807 # if not, fall back to the user specified behavior
#     808 else:
# --> 809     ret = base_connection_style(posA, posB, *args, **kwargs)
#     811 return ret
#
# File /usr/local/lib/python3.8/dist-packages/matplotlib/patches.py:2768, in ConnectionStyle._Base.__call__(self, posA, posB, shrinkA, shrinkB, patchA, patchB)
#    2766 path = self.connect(posA, posB)
#    2767 clipped_path = self._clip(path, patchA, patchB)
# -> 2768 shrunk_path = self._shrink(clipped_path, shrinkA, shrinkB)
#    2769 return shrunk_path
#
# File /usr/local/lib/python3.8/dist-packages/matplotlib/patches.py:2749, in ConnectionStyle._Base._shrink(self, path, shrinkA, shrinkB)
#    2747 insideA = inside_circle(*path.vertices[0], shrinkA)
#    2748 try:
# -> 2749     left, path = split_path_inout(path, insideA)
#    2750 except ValueError:
#    2751     pass
#
# File /usr/local/lib/python3.8/dist-packages/matplotlib/bezier.py:392, in split_path_inout(path, inside, tolerance, reorder_inout)
#     389     path_out = Path(np.concatenate([verts_right, path.vertices[i:]]))
#     391 else:
# --> 392     path_in = Path(np.concatenate([path.vertices[:iold], verts_left]),
#     393                    np.concatenate([path.codes[:iold], codes_left]))
#     395     path_out = Path(np.concatenate([verts_right, path.vertices[i:]]),
#     396                     np.concatenate([codes_right, path.codes[i:]]))
#     398 if reorder_inout and not begin_inside:
#
# File <__array_function__ internals>:180, in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# # Caso 4: dirigido, diferentes tamaños, balanceado, clases separadas, features aplanadas
#
# Grafos iguales a los del caso 1, salvo que las features están aplanadas a 1

# %%
class synthetic_Dir_diffSize_balanced_clasesSep_flattened(Dataset):
    
    def __init__(self, **kwargs):
        super().__init__(**kwargs)

    @property
    def path(self):
        return os.path.join(DATASET_FOLDER, "syntheticGraphs", self.__class__.__name__)
    
    def download(self):
        os.makedirs(self.path)
        
        def generate_synthetic_graph_csbm(n_nodes, n_communities, n_features, edge_prob_matrix, node_feature_means,\
                                  semilla, indice, feature_cov_matrix=None):
            # Assign nodes to communities
            np.random.seed(semilla*(indice+1))
            communities = np.random.randint(0, n_communities, n_nodes)

            # Generate node features
            if feature_cov_matrix is None:
                feature_cov_matrix = np.eye(n_features)
            features = np.zeros((n_nodes, n_features))
            for k in range(n_communities):
                nodes_in_community = np.where(communities == k)[0]
                features[nodes_in_community] = np.random.multivariate_normal(node_feature_means[k], feature_cov_matrix,\
                                                                             len(nodes_in_community))

            # Compute community membership probabilities based on node features
            community_membership_probs = softmax(features @ node_feature_means.T, axis=1)

            # Generate edges based on community membership probabilities
            adjacency_matrix = np.zeros((n_nodes, n_nodes))
            for i in range(n_nodes):
                for j in range(n_nodes):
                    if i == j:
                        continue
                    community_i = communities[i]
                    community_j = communities[j]
                    edge_prob = edge_prob_matrix[community_i, community_j] * community_membership_probs[i, community_j] * community_membership_probs[j, community_i]
                    adjacency_matrix[i, j] = np.random.binomial(1, edge_prob)

            labels = tf.keras.utils.to_categorical(communities)
            adjacency_matrix = sparse.csr_matrix(adjacency_matrix)
            return Graph(x=np.ones((n_nodes, n_features)), a=adjacency_matrix, y=labels)

        
        n_graphs = 10
        n_nodes = [25, 50, 100, 200, 400, 800, 1600, 3200, 6400, 12800]
        n_features = 2
        n_classes = 2
        # Probability matrix for edges between communities
        edge_prob_matrix = np.array([
                                        [0.8, 0.2],
                                        [0.3, 0.7]
                                    ])
        # Node feature means for each community
        node_feature_means = np.array([
                                        [2, 1], #, 0, 0, 0],
                                        [1, 2] #, 0, 0, 0]
                                    ])
        
        semillas = [123, 234, 345, 456, 567, 678, 789, 321, 654, 987]
        
        # Bien separadas las clases:
        graphs1 = [generate_synthetic_graph_csbm(n_nodes[i], n_classes, n_features, edge_prob_matrix, node_feature_means, semillas[i], 0, feature_cov_matrix=None) for i in range(n_graphs)]
        for j in range(10):
            filename = os.path.join(self.path, f'graph_Dir_{n_nodes[j]}nodes_balanced_clasesSep_0{j}_flattened.npz')
            np.savez(filename, x=graphs1[j].x, a=graphs1[j].a, y=graphs1[j].y)

        # Free memory
        del graphs1
        gc.collect()


    def read(self):
        # We must return a list of Graph objects
        output = []

        n_nodes = [25, 50, 100, 200, 400, 800, 1600, 3200, 6400, 12800]
        
        for j in range(10):
            data1 = np.load(os.path.join(self.path, f'graph_Dir_{n_nodes[j]}nodes_balanced_clasesSep_0{j}_flattened.npz'), allow_pickle=True)
            output.append(
                Graph(x=data1['x'], a=data1['a'][()], y=data1['y']) # también puede ser a=data['a'].item()
            )

        return output

# %%
dataset4 = synthetic_Dir_diffSize_balanced_clasesSep_flattened()

# %% [markdown]
# # Caso 5: dirigido, diferentes tamaños, balanceado, clases más juntas, features aplanadas
#
# Grafos iguales a los del caso 2, salvo que las features están aplanadas a 1

# %%
class synthetic_Dir_diffSize_balanced_clasesJunt_flattened(Dataset):
    
    def __init__(self, **kwargs):
        super().__init__(**kwargs)

    @property
    def path(self):
        return os.path.join(DATASET_FOLDER, "syntheticGraphs", self.__class__.__name__)
    
    def download(self):
        os.makedirs(self.path)
        
        def generate_synthetic_graph_csbm(n_nodes, n_communities, n_features, edge_prob_matrix, node_feature_means,\
                                  semilla, indice, feature_cov_matrix=None):
            # Assign nodes to communities
            np.random.seed(semilla*(indice+1))
            communities = np.random.randint(0, n_communities, n_nodes)

            # Generate node features
            if feature_cov_matrix is None:
                feature_cov_matrix = np.eye(n_features)
            features = np.zeros((n_nodes, n_features))
            for k in range(n_communities):
                nodes_in_community = np.where(communities == k)[0]
                features[nodes_in_community] = np.random.multivariate_normal(node_feature_means[k], feature_cov_matrix,\
                                                                             len(nodes_in_community))

            # Compute community membership probabilities based on node features
            community_membership_probs = softmax(features @ node_feature_means.T, axis=1)

            # Generate edges based on community membership probabilities
            adjacency_matrix = np.zeros((n_nodes, n_nodes))
            for i in range(n_nodes):
                for j in range(n_nodes):
                    if i == j:
                        continue
                    community_i = communities[i]
                    community_j = communities[j]
                    edge_prob = edge_prob_matrix[community_i, community_j] * community_membership_probs[i, community_j] * community_membership_probs[j, community_i]
                    adjacency_matrix[i, j] = np.random.binomial(1, edge_prob)

            labels = tf.keras.utils.to_categorical(communities)
            adjacency_matrix = sparse.csr_matrix(adjacency_matrix)
            return Graph(x=np.ones((n_nodes, n_features)), a=adjacency_matrix, y=labels)

        
        n_graphs = 10
        n_nodes = [25, 50, 100, 200, 400, 800, 1600, 3200, 6400, 12800]
        n_features = 2
        n_classes = 2
        # Probability matrix for edges between communities
        edge_prob_matrix = np.array([
                                    [0.5, 0.5],
                                    [0.5, 0.5]
                            ])
        # Node feature means for each community
        node_feature_means = np.array([
                                        [2, 1], #, 0, 0, 0],
                                        [1, 2] #, 0, 0, 0]
                                    ])
        
        semillas = [123, 234, 345, 456, 567, 678, 789, 321, 654, 987]
        
        # Clases un poco más juntas:
        graphs2 = [generate_synthetic_graph_csbm(n_nodes[i], n_classes, n_features, edge_prob_matrix, node_feature_means, semillas[i], 1, feature_cov_matrix=None) for i in range(n_graphs)]
        for j in range(10):
            filename = os.path.join(self.path, f'graph_Dir_{n_nodes[j]}nodes_balanced_clasesJunt_1{j}_flattened.npz')
            np.savez(filename, x=graphs2[j].x, a=graphs2[j].a, y=graphs2[j].y)

        # Free memory
        del graphs2
        gc.collect()


    def read(self):
        # We must return a list of Graph objects
        output = []

        n_nodes = [25, 50, 100, 200, 400, 800, 1600, 3200, 6400, 12800]
        
        for j in range(10):
            data2 = np.load(os.path.join(self.path, f'graph_Dir_{n_nodes[j]}nodes_balanced_clasesJunt_1{j}_flattened.npz'), allow_pickle=True)
            output.append(
                Graph(x=data2['x'], a=data2['a'][()], y=data2['y']) # también puede ser a=data['a'].item()
            )

        return output

# %%
dataset5 = synthetic_Dir_diffSize_balanced_clasesJunt_flattened()

# %% [markdown]
# # Caso 6: dirigido, diferentes tamaños, balanceado, clases mezcladas, features aplanadas
#
# Grafos iguales a los del caso 3, salvo que las features están aplanadas a 1

# %%
class synthetic_Dir_diffSize_balanced_clasesMezcl_flattened(Dataset):
    
    def __init__(self, **kwargs):
        super().__init__(**kwargs)

    @property
    def path(self):
        return os.path.join(DATASET_FOLDER, "syntheticGraphs", self.__class__.__name__)
    
    def download(self):
        os.makedirs(self.path)
        
        def generate_synthetic_graph_csbm(n_nodes, n_communities, n_features, edge_prob_matrix, node_feature_means,\
                                  semilla, indice, feature_cov_matrix=None):
            # Assign nodes to communities
            np.random.seed(semilla*(indice+1))
            communities = np.random.randint(0, n_communities, n_nodes)

            # Generate node features
            if feature_cov_matrix is None:
                feature_cov_matrix = np.eye(n_features)
            features = np.zeros((n_nodes, n_features))
            for k in range(n_communities):
                nodes_in_community = np.where(communities == k)[0]
                features[nodes_in_community] = np.random.multivariate_normal(node_feature_means[k], feature_cov_matrix,\
                                                                             len(nodes_in_community))

            # Compute community membership probabilities based on node features
            community_membership_probs = softmax(features @ node_feature_means.T, axis=1)

            # Generate edges based on community membership probabilities
            adjacency_matrix = np.zeros((n_nodes, n_nodes))
            for i in range(n_nodes):
                for j in range(n_nodes):
                    if i == j:
                        continue
                    community_i = communities[i]
                    community_j = communities[j]
                    edge_prob = edge_prob_matrix[community_i, community_j] * community_membership_probs[i, community_j] * community_membership_probs[j, community_i]
                    adjacency_matrix[i, j] = np.random.binomial(1, edge_prob)

            labels = tf.keras.utils.to_categorical(communities)
            adjacency_matrix = sparse.csr_matrix(adjacency_matrix)
            return Graph(x=np.ones((n_nodes, n_features)), a=adjacency_matrix, y=labels)

        
        n_graphs = 10
        n_nodes = [25, 50, 100, 200, 400, 800, 1600, 3200, 6400, 12800]
        n_features = 2
        n_classes = 2
        # Probability matrix for edges between communities
        edge_prob_matrix = np.array([
                                    [0.5, 0.5],
                                    [0.5, 0.5]
                            ])
        # Node feature means for each community
        node_feature_means = np.array([
                                        [1, 1], #, 0, 0, 0],
                                        [1, 1] #, 0, 0, 0]
                                    ])
        
        semillas = [123, 234, 345, 456, 567, 678, 789, 321, 654, 987]
        
        # Clases completamente mezcladas:
        graphs3 = [generate_synthetic_graph_csbm(n_nodes[i], n_classes, n_features, edge_prob_matrix, node_feature_means, semillas[i], 2, feature_cov_matrix=None) for i in range(n_graphs)]
        for j in range(10):
            filename = os.path.join(self.path, f'graph_Dir_{n_nodes[j]}nodes_balanced_clasesMezcl_2{j}_flattened.npz')
            np.savez(filename, x=graphs3[j].x, a=graphs3[j].a, y=graphs3[j].y)
            
        # Free memory
        del graphs3
        gc.collect()


    def read(self):
        # We must return a list of Graph objects
        output = []

        n_nodes = [25, 50, 100, 200, 400, 800, 1600, 3200, 6400, 12800]
        
        for j in range(10):
            data3 = np.load(os.path.join(self.path, f'graph_Dir_{n_nodes[j]}nodes_balanced_clasesMezcl_2{j}_flattened.npz'), allow_pickle=True)
            output.append(
                Graph(x=data3['x'], a=data3['a'][()], y=data3['y']) # también puede ser a=data['a'].item()
            )

        return output

# %%
dataset6 = synthetic_Dir_diffSize_balanced_clasesMezcl_flattened()
