# %%
# !pip install networkx
# Out:
# Requirement already satisfied: networkx in /usr/local/lib/python3.8/dist-packages (3.1)
# WARNING: You are using pip version 20.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      |████████████████████████████████| 293 kB 928 kB/s eta 0:00:01
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /usr/local/lib/python3.8/dist-packages (from seaborn) (3.6.2)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.8/dist-packages (from seaborn) (1.5.3)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /usr/local/lib/python3.8/dist-packages (from seaborn) (1.23.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.3.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.14.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.12.2
# WARNING: You are using pip version 20.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import networkx as nx

import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

from spektral.data import Dataset, Graph
from spektral.layers import GraphSageConv
from spektral.utils import normalized_adjacency
from spektral.models.gcn import GCN 

from scipy import sparse
from scipy.special import softmax

from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Function to plotting a graph

# %%
def plot_graph(G, communities=None):
    pos = nx.spring_layout(G, seed=42)
    
    if communities is not None:
        # Assign colors to nodes based on their communities
        colors = ['orange' if community == 0 else 'skyblue' for community in communities]
    else:
        colors = 'red'

    nx.draw(G, pos, node_color=colors, with_labels=True)
    plt.show()

# %% [markdown]
# ## CSBM Generation - GRAFOS DIRIGIDOS (matriz adyacencia NO simétrica)

# %%
def generate_synthetic_graph_csbm(n_nodes, n_communities, n_features, edge_prob_matrix, node_feature_means,\
                                  feature_cov_matrix=None):
    # Assign nodes to communities
    communities = np.random.randint(0, n_communities, n_nodes)

    # Generate node features
    if feature_cov_matrix is None:
        feature_cov_matrix = np.eye(n_features)
    features = np.zeros((n_nodes, n_features))
    for k in range(n_communities):
        nodes_in_community = np.where(communities == k)[0]
        features[nodes_in_community] = np.random.multivariate_normal(node_feature_means[k], feature_cov_matrix,\
                                                                     len(nodes_in_community))

    # Compute community membership probabilities based on node features
    community_membership_probs = softmax(features @ node_feature_means.T, axis=1)

    # Generate edges based on community membership probabilities
    adjacency_matrix = np.zeros((n_nodes, n_nodes))
    for i in range(n_nodes):
        for j in range(i, n_nodes):
            if i == j:
                continue
            community_i = communities[i]
            community_j = communities[j]
            edge_prob = edge_prob_matrix[community_i, community_j] * community_membership_probs[i, community_j] * community_membership_probs[j, community_i]
            adjacency_matrix[i, j] = np.random.binomial(1, edge_prob)
            adjacency_matrix[j, i] = np.random.binomial(1, edge_prob)

    labels = tf.keras.utils.to_categorical(communities)
    adjacency_matrix = sparse.csr_matrix(adjacency_matrix)
    return Graph(x=features, a=adjacency_matrix, y=labels)

    #return adjacency_matrix, features, communities

# %% [markdown]
# ### Class for generating synthetic datasets

# %%
class SyntheticDataset(Dataset):
    def __init__(self, graphs=None, **kwargs):
        self.graphs = graphs
        super().__init__(**kwargs)

    def read(self):
        return self.graphs

# %% [markdown]
# ### Generating graphs

# %%
n_graphs = 2
n_nodes = 100
n_features = 2
n_classes = 2
# Probability matrix for edges between communities
edge_prob_matrix = np.array([
    [0.8, 0.2],
    [0.3, 0.7]
])

# Node feature means for each community
node_feature_means = np.array([
    [2, 1], #, 0, 0, 0],
    [1, 2] #, 0, 0, 0]
])


graphs = [generate_synthetic_graph_csbm(n_nodes, n_classes, n_features, edge_prob_matrix, node_feature_means, feature_cov_matrix=None) for _ in range(n_graphs)]

# %%
for G in graphs:
    nxG = nx.from_numpy_array(G.a)
    labels = np.argmax(G.y,axis=1)
    plot_graph(nxG,labels)

# %%
train_graphs, test_graphs = train_test_split(graphs, test_size=0.5, random_state=42)
train_dataset = SyntheticDataset(train_graphs)
test_dataset = SyntheticDataset(test_graphs)

# %%
from spektral.data import BatchLoader,DisjointLoader,SingleLoader
batch_size = 1

# Create data loaders for training and testing data
#train_loader = BatchLoader(train_dataset, batch_size=batch_size)
#test_loader = BatchLoader(test_dataset, batch_size=batch_size)

train_loader = SingleLoader(train_dataset)
test_loader = SingleLoader(test_dataset)

# %%
model = GCN(n_labels=n_classes,channels=16,l2_reg=1.0000,dropout_rate=0)

# %%
# Compile the model
model.compile(optimizer=Adam(learning_rate=0.01), loss="binary_crossentropy", metrics=["accuracy"])

# Define early stopping to prevent overfitting
es_callback = EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True)

# Train the model
history = model.fit(
    train_loader.load(),
    steps_per_epoch=train_loader.steps_per_epoch,
    epochs=100,
    validation_data=test_loader.load(),
    validation_steps=test_loader.steps_per_epoch#,
    #callbacks=[es_callback],
)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 54.8491 - accuracy: 0.4800 - val_loss: 59.0142 - val_accuracy: 0.5200
# Epoch 2/100
# 1/1 [==============================] - 0s 13ms/step - loss: 45.8432 - accuracy: 0.4800 - val_loss: 47.8151 - val_accuracy: 0.6600
# Epoch 3/100
# 1/1 [==============================] - 0s 13ms/step - loss: 37.3284 - accuracy: 0.7300 - val_loss: 37.4048 - val_accuracy: 0.7800
# Epoch 4/100
# 1/1 [==============================] - 0s 13ms/step - loss: 29.1622 - accuracy: 0.8900 - val_loss: 27.5722 - val_accuracy: 0.8600
# Epoch 5/100
# 1/1 [==============================] - 0s 11ms/step - loss: 21.3072 - accuracy: 0.9200 - val_loss: 18.6979 - val_accuracy: 0.8800
# Epoch 6/100
# 1/1 [==============================] - 0s 11ms/step - loss: 13.8567 - accuracy: 0.9400 - val_loss: 11.6232 - val_accuracy: 0.8900
# Epoch 7/100
# 1/1 [==============================] - 0s 11ms/step - loss: 6.8895 - accuracy: 0.9500 - val_loss: 6.3374 - val_accuracy: 0.9000
# Epoch 8/100
# 1/1 [==============================] - 0s 14ms/step - loss: 4.5576 - accuracy: 0.9600 - val_loss: 5.1718 - val_accuracy: 0.9200
# Epoch 9/100
# 1/1 [==============================] - 0s 14ms/step - loss: 3.8770 - accuracy: 0.9600 - val_loss: 4.9667 - val_accuracy: 0.9300
# Epoch 10/100
# 1/1 [==============================] - 0s 14ms/step - loss: 3.8484 - accuracy: 0.9600 - val_loss: 4.8206 - val_accuracy: 0.9300
# Epoch 11/100
# 1/1 [==============================] - 0s 12ms/step - loss: 3.8495 - accuracy: 0.9600 - val_loss: 4.7252 - val_accuracy: 0.9400
# Epoch 12/100
# 1/1 [==============================] - 0s 13ms/step - loss: 3.8608 - accuracy: 0.9600 - val_loss: 4.6590 - val_accuracy: 0.9400
# Epoch 13/100
# 1/1 [==============================] - 0s 12ms/step - loss: 3.8731 - accuracy: 0.9600 - val_loss: 4.6163 - val_accuracy: 0.9400
# Epoch 14/100
# 1/1 [==============================] - 0s 13ms/step - loss: 3.8830 - accuracy: 0.9600 - val_loss: 4.6107 - val_accuracy: 0.9400
# Epoch 15/100
# 1/1 [==============================] - 0s 13ms/step - loss: 3.8845 - accuracy: 0.9600 - val_loss: 4.6554 - val_accuracy: 0.9400
# Epoch 16/100
# 1/1 [==============================] - 0s 14ms/step - loss: 3.8791 - accuracy: 0.9600 - val_loss: 4.7455 - val_accuracy: 0.9300
# Epoch 17/100
# 1/1 [==============================] - 0s 14ms/step - loss: 3.8691 - accuracy: 0.9600 - val_loss: 4.8981 - val_accuracy: 0.9200
# Epoch 18/100
# 1/1 [==============================] - 0s 14ms/step - loss: 3.8637 - accuracy: 0.9600 - val_loss: 5.0617 - val_accuracy: 0.9100
# Epoch 19/100
# 1/1 [==============================] - 0s 12ms/step - loss: 3.8617 - accuracy: 0.9600 - val_loss: 5.1733 - val_accuracy: 0.9100
# Epoch 20/100
# 1/1 [==============================] - 0s 11ms/step - loss: 3.8545 - accuracy: 0.9600 - val_loss: 5.2372 - val_accuracy: 0.9100
# Epoch 21/100
# 1/1 [==============================] - 0s 13ms/step - loss: 3.8406 - accuracy: 0.9600 - val_loss: 5.2568 - val_accuracy: 0.9100
# Epoch 22/100
# 1/1 [==============================] - 0s 12ms/step - loss: 3.8209 - accuracy: 0.9600 - val_loss: 5.2411 - val_accuracy: 0.9100
# Epoch 23/100
# 1/1 [==============================] - 0s 12ms/step - loss: 3.7968 - accuracy: 0.9600 - val_loss: 5.1985 - val_accuracy: 0.9100
# Epoch 24/100
# 1/1 [==============================] - 0s 12ms/step - loss: 3.7706 - accuracy: 0.9600 - val_loss: 5.1381 - val_accuracy: 0.9100
# Epoch 25/100
# 1/1 [==============================] - 0s 12ms/step - loss: 3.7409 - accuracy: 0.9600 - val_loss: 5.0661 - val_accuracy: 0.9100
# Epoch 26/100
# 1/1 [==============================] - 0s 12ms/step - loss: 3.7098 - accuracy: 0.9600 - val_loss: 4.9953 - val_accuracy: 0.9100
# Epoch 27/100
# 1/1 [==============================] - 0s 12ms/step - loss: 3.6781 - accuracy: 0.9600 - val_loss: 4.9286 - val_accuracy: 0.9100
# Epoch 28/100
# 1/1 [==============================] - 0s 11ms/step - loss: 3.6464 - accuracy: 0.9600 - val_loss: 4.8697 - val_accuracy: 0.9100
# Epoch 29/100
# 1/1 [==============================] - 0s 12ms/step - loss: 3.6142 - accuracy: 0.9600 - val_loss: 4.8185 - val_accuracy: 0.9100
# Epoch 30/100
# 1/1 [==============================] - 0s 14ms/step - loss: 3.5815 - accuracy: 0.9600 - val_loss: 4.7790 - val_accuracy: 0.9100
# Epoch 31/100
# 1/1 [==============================] - 0s 13ms/step - loss: 3.5487 - accuracy: 0.9600 - val_loss: 4.7567 - val_accuracy: 0.9000
# Epoch 32/100
# 1/1 [==============================] - 0s 14ms/step - loss: 3.5155 - accuracy: 0.9600 - val_loss: 4.7566 - val_accuracy: 0.9000
# Epoch 33/100
# 1/1 [==============================] - 0s 12ms/step - loss: 3.4817 - accuracy: 0.9600 - val_loss: 4.7943 - val_accuracy: 0.9000
# Epoch 34/100
# 1/1 [==============================] - 0s 14ms/step - loss: 3.4480 - accuracy: 0.9600 - val_loss: 4.8593 - val_accuracy: 0.8900
# Epoch 35/100
# 1/1 [==============================] - 0s 14ms/step - loss: 3.4137 - accuracy: 0.9600 - val_loss: 4.9518 - val_accuracy: 0.8900
# Epoch 36/100
# 1/1 [==============================] - 0s 13ms/step - loss: 3.3798 - accuracy: 0.9500 - val_loss: 5.0323 - val_accuracy: 0.8900
# Epoch 37/100
# 1/1 [==============================] - 0s 13ms/step - loss: 3.3519 - accuracy: 0.9500 - val_loss: 5.0241 - val_accuracy: 0.8900
# Epoch 38/100
# 1/1 [==============================] - 0s 13ms/step - loss: 3.3228 - accuracy: 0.9500 - val_loss: 4.9102 - val_accuracy: 0.8900
# Epoch 39/100
# 1/1 [==============================] - 0s 12ms/step - loss: 3.2868 - accuracy: 0.9500 - val_loss: 4.7096 - val_accuracy: 0.8900
# Epoch 40/100
# 1/1 [==============================] - 0s 13ms/step - loss: 3.2472 - accuracy: 0.9500 - val_loss: 4.4826 - val_accuracy: 0.8900
# Epoch 41/100
# 1/1 [==============================] - 0s 12ms/step - loss: 3.2129 - accuracy: 0.9600 - val_loss: 4.3078 - val_accuracy: 0.9000
# Epoch 42/100
# 1/1 [==============================] - 0s 12ms/step - loss: 3.1818 - accuracy: 0.9600 - val_loss: 4.1899 - val_accuracy: 0.9000
# Epoch 43/100
# 1/1 [==============================] - 0s 14ms/step - loss: 3.1487 - accuracy: 0.9600 - val_loss: 4.1216 - val_accuracy: 0.9000
# Epoch 44/100
# 1/1 [==============================] - 0s 13ms/step - loss: 3.1126 - accuracy: 0.9600 - val_loss: 4.0942 - val_accuracy: 0.9000
# Epoch 45/100
# 1/1 [==============================] - 0s 13ms/step - loss: 3.0742 - accuracy: 0.9600 - val_loss: 4.0986 - val_accuracy: 0.8900
# Epoch 46/100
# 1/1 [==============================] - 0s 12ms/step - loss: 3.0357 - accuracy: 0.9600 - val_loss: 4.1025 - val_accuracy: 0.8900
# Epoch 47/100
# 1/1 [==============================] - 0s 11ms/step - loss: 2.9989 - accuracy: 0.9600 - val_loss: 4.0534 - val_accuracy: 0.8900
# Epoch 48/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.9606 - accuracy: 0.9600 - val_loss: 3.9408 - val_accuracy: 0.8900
# Epoch 49/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.9206 - accuracy: 0.9600 - val_loss: 3.8048 - val_accuracy: 0.8900
# Epoch 50/100
# 1/1 [==============================] - 0s 14ms/step - loss: 2.8823 - accuracy: 0.9600 - val_loss: 3.6702 - val_accuracy: 0.9000
# Epoch 51/100
# 1/1 [==============================] - 0s 11ms/step - loss: 2.8446 - accuracy: 0.9600 - val_loss: 3.5457 - val_accuracy: 0.9000
# Epoch 52/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.8062 - accuracy: 0.9600 - val_loss: 3.4348 - val_accuracy: 0.9000
# Epoch 53/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.7664 - accuracy: 0.9600 - val_loss: 3.3516 - val_accuracy: 0.9000
# Epoch 54/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.7245 - accuracy: 0.9600 - val_loss: 3.2860 - val_accuracy: 0.9000
# Epoch 55/100
# 1/1 [==============================] - 0s 14ms/step - loss: 2.6827 - accuracy: 0.9600 - val_loss: 3.1926 - val_accuracy: 0.9000
# Epoch 56/100
# 1/1 [==============================] - 0s 14ms/step - loss: 2.6411 - accuracy: 0.9600 - val_loss: 3.0493 - val_accuracy: 0.9000
# Epoch 57/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.5991 - accuracy: 0.9600 - val_loss: 2.9004 - val_accuracy: 0.9000
# Epoch 58/100
# 1/1 [==============================] - 0s 14ms/step - loss: 2.5604 - accuracy: 0.9600 - val_loss: 2.7796 - val_accuracy: 0.9300
# Epoch 59/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.5363 - accuracy: 0.9600 - val_loss: 2.6091 - val_accuracy: 0.9600
# Epoch 60/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.7353 - accuracy: 0.9500 - val_loss: 3.8158 - val_accuracy: 0.8700
# Epoch 61/100
# 1/1 [==============================] - 0s 12ms/step - loss: 4.7848 - accuracy: 0.9300 - val_loss: 2.4911 - val_accuracy: 0.9600
# Epoch 62/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.5410 - accuracy: 0.9500 - val_loss: 2.5810 - val_accuracy: 0.9900
# Epoch 63/100
# 1/1 [==============================] - 0s 13ms/step - loss: 3.2191 - accuracy: 0.9000 - val_loss: 2.4692 - val_accuracy: 0.9900
# Epoch 64/100
# 1/1 [==============================] - 0s 14ms/step - loss: 3.0914 - accuracy: 0.9000 - val_loss: 2.3591 - val_accuracy: 0.9900
# Epoch 65/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.7663 - accuracy: 0.9000 - val_loss: 2.3670 - val_accuracy: 0.9800
# Epoch 66/100
# 1/1 [==============================] - 0s 14ms/step - loss: 2.6300 - accuracy: 0.9100 - val_loss: 2.4263 - val_accuracy: 0.9700
# Epoch 67/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.5470 - accuracy: 0.9400 - val_loss: 2.5166 - val_accuracy: 0.9600
# Epoch 68/100
# 1/1 [==============================] - 0s 14ms/step - loss: 2.4925 - accuracy: 0.9500 - val_loss: 2.6348 - val_accuracy: 0.9400
# Epoch 69/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.4633 - accuracy: 0.9600 - val_loss: 2.7809 - val_accuracy: 0.9300
# Epoch 70/100
# 1/1 [==============================] - 0s 14ms/step - loss: 2.4479 - accuracy: 0.9600 - val_loss: 2.9465 - val_accuracy: 0.9000
# Epoch 71/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.4399 - accuracy: 0.9600 - val_loss: 3.1106 - val_accuracy: 0.8900
# Epoch 72/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.4363 - accuracy: 0.9600 - val_loss: 3.2453 - val_accuracy: 0.8800
# Epoch 73/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.4331 - accuracy: 0.9500 - val_loss: 3.3392 - val_accuracy: 0.8800
# Epoch 74/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.4286 - accuracy: 0.9400 - val_loss: 3.3828 - val_accuracy: 0.8800
# Epoch 75/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.4200 - accuracy: 0.9400 - val_loss: 3.3749 - val_accuracy: 0.8800
# Epoch 76/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.4058 - accuracy: 0.9400 - val_loss: 3.3286 - val_accuracy: 0.8800
# Epoch 77/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.3883 - accuracy: 0.9400 - val_loss: 3.2652 - val_accuracy: 0.8800
# Epoch 78/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.3717 - accuracy: 0.9500 - val_loss: 3.2031 - val_accuracy: 0.8900
# Epoch 79/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.3579 - accuracy: 0.9500 - val_loss: 3.1486 - val_accuracy: 0.8900
# Epoch 80/100
# 1/1 [==============================] - 0s 15ms/step - loss: 2.3459 - accuracy: 0.9500 - val_loss: 3.0999 - val_accuracy: 0.8900
# Epoch 81/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.3345 - accuracy: 0.9600 - val_loss: 3.0553 - val_accuracy: 0.8900
# Epoch 82/100
# 1/1 [==============================] - 0s 11ms/step - loss: 2.3210 - accuracy: 0.9600 - val_loss: 3.0186 - val_accuracy: 0.9000
# Epoch 83/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.3024 - accuracy: 0.9600 - val_loss: 2.9915 - val_accuracy: 0.8900
# Epoch 84/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.2780 - accuracy: 0.9600 - val_loss: 2.9724 - val_accuracy: 0.8900
# Epoch 85/100
# 1/1 [==============================] - 0s 11ms/step - loss: 2.2516 - accuracy: 0.9600 - val_loss: 2.9596 - val_accuracy: 0.8900
# Epoch 86/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.2275 - accuracy: 0.9500 - val_loss: 2.9505 - val_accuracy: 0.8900
# Epoch 87/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.2078 - accuracy: 0.9500 - val_loss: 2.9336 - val_accuracy: 0.8900
# Epoch 88/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.1913 - accuracy: 0.9500 - val_loss: 2.8912 - val_accuracy: 0.8900
# Epoch 89/100
# 1/1 [==============================] - 0s 14ms/step - loss: 2.1745 - accuracy: 0.9500 - val_loss: 2.8166 - val_accuracy: 0.8900
# Epoch 90/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.1556 - accuracy: 0.9600 - val_loss: 2.7216 - val_accuracy: 0.9000
# Epoch 91/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.1358 - accuracy: 0.9600 - val_loss: 2.6281 - val_accuracy: 0.9000
# Epoch 92/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.1178 - accuracy: 0.9600 - val_loss: 2.5494 - val_accuracy: 0.9000
# Epoch 93/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.1027 - accuracy: 0.9600 - val_loss: 2.4917 - val_accuracy: 0.9000
# Epoch 94/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.0888 - accuracy: 0.9600 - val_loss: 2.4599 - val_accuracy: 0.9100
# Epoch 95/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.0723 - accuracy: 0.9600 - val_loss: 2.4549 - val_accuracy: 0.9000
# Epoch 96/100
# 1/1 [==============================] - 0s 14ms/step - loss: 2.0536 - accuracy: 0.9600 - val_loss: 2.4755 - val_accuracy: 0.9000
# Epoch 97/100
# 1/1 [==============================] - 0s 14ms/step - loss: 2.0379 - accuracy: 0.9600 - val_loss: 2.4987 - val_accuracy: 0.9000
# Epoch 98/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.0261 - accuracy: 0.9600 - val_loss: 2.4606 - val_accuracy: 0.9000
# Epoch 99/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.0096 - accuracy: 0.9600 - val_loss: 2.3826 - val_accuracy: 0.9000
# Epoch 100/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.9920 - accuracy: 0.9600 - val_loss: 2.3298 - val_accuracy: 0.9100

# %%
import pandas as pd
res=pd.DataFrame(history.history)

# Add row index as a new column
res.reset_index(inplace=True)

# Rename the new column to 'row_id'
res.rename(columns={'index': 'epoch'}, inplace=True)
res
# Out:
#     epoch       loss  accuracy   val_loss  val_accuracy
# 0       0  54.849117      0.48  59.014160          0.52
# 1       1  45.843185      0.48  47.815086          0.66
# 2       2  37.328362      0.73  37.404839          0.78
# 3       3  29.162195      0.89  27.572163          0.86
# 4       4  21.307190      0.92  18.697891          0.88
# ..    ...        ...       ...        ...           ...
# 95     95   2.053633      0.96   2.475458          0.90
# 96     96   2.037882      0.96   2.498677          0.90
# 97     97   2.026093      0.96   2.460596          0.90
# 98     98   2.009583      0.96   2.382616          0.90
# 99     99   1.992037      0.96   2.329789          0.91
#
# [100 rows x 5 columns]

# %%
history.history['accuracy']

import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="whitegrid")
line1 = sns.lineplot(x="epoch", y='loss', data=res, label='Training Loss')
line2 = sns.lineplot(x="epoch", y='val_loss', data=res, label='Test Loss')


# Add points to each observation
scatter1 = sns.scatterplot(x="epoch", y='loss', data=res, marker='o', color='skyblue')
scatter2 = sns.scatterplot(x="epoch", y='val_loss', data=res, marker='o', color='orange')

# Change the y-axis label
plt.ylabel("Loss Value")

# Create a legend for the lines
plt.legend()

# Show the plot
plt.show()

# %%
sns.set_theme(style="whitegrid")
line1 = sns.lineplot(x="epoch", y="accuracy", data=res, label='Training Accuracy')
line2 = sns.lineplot(x="epoch", y="val_accuracy", data=res, label='Test Accuracy')

# Add points to each observation
scatter1 = sns.scatterplot(x="epoch", y="accuracy", data=res, marker='o', color='skyblue')
scatter2 = sns.scatterplot(x="epoch", y="val_accuracy", data=res, marker='o', color='orange')

# Change the y-axis label
plt.ylabel("Accuracy Value")

# Create a legend for the lines
plt.legend()

# Show the plot
plt.show()

# %%
predictions = []
targets = []
step = 0
while step < test_loader.steps_per_epoch:
        step += 1
        inputs, target = test_loader.__next__()
        pred = model(inputs, training=False)
        predictions.append(pred)
        targets.append(target)
    
predictions = np.vstack(predictions)
    
targets = np.vstack(targets)
# Post-process the predictions if necessary (e.g., convert probabilities to class labels)
predicted_values = np.argmax(predictions, axis=1)
true_labels = np.argmax(targets,axis =1 )

# %%
from sklearn.metrics import confusion_matrix,roc_auc_score,accuracy_score
conf_mat = confusion_matrix(predicted_values, true_labels)
print(conf_mat)
# Out:
# [[52  9]
#  [ 0 39]]

# %%
auc_score = roc_auc_score(true_labels, predicted_values)
accuracy_score = accuracy_score(true_labels, predicted_values)

print("AUC Score:", auc_score)
print("Accuracy Score:", accuracy_score)
# Out:
# AUC Score: 0.90625
# Accuracy Score: 0.91
