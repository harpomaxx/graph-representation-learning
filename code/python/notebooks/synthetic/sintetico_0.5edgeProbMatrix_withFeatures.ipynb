# %%
# !pip install networkx
# Out:
# Requirement already satisfied: networkx in /usr/local/lib/python3.8/dist-packages (3.1)
# WARNING: You are using pip version 20.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      |████████████████████████████████| 293 kB 928 kB/s eta 0:00:01
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /usr/local/lib/python3.8/dist-packages (from seaborn) (3.6.2)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.8/dist-packages (from seaborn) (1.5.3)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /usr/local/lib/python3.8/dist-packages (from seaborn) (1.23.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.3.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.14.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.12.2
# WARNING: You are using pip version 20.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import networkx as nx

import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

from spektral.data import Dataset, Graph
from spektral.layers import GraphSageConv
from spektral.utils import normalized_adjacency
from spektral.models.gcn import GCN 

from scipy import sparse
from scipy.special import softmax

from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Function to plotting a graph

# %%
def plot_graph(G, communities=None):
    pos = nx.spring_layout(G, seed=42)
    
    if communities is not None:
        # Assign colors to nodes based on their communities
        colors = ['orange' if community == 0 else 'skyblue' for community in communities]
    else:
        colors = 'red'

    nx.draw(G, pos, node_color=colors, with_labels=True)
    plt.show()

# %% [markdown]
# ## CSBM Generation - Caso base

# %%
def generate_synthetic_graph_csbm(n_nodes, n_communities, n_features, edge_prob_matrix, node_feature_means,\
                                  feature_cov_matrix=None):
    # Assign nodes to communities
    communities = np.random.randint(0, n_communities, n_nodes)

    # Generate node features
    if feature_cov_matrix is None:
        feature_cov_matrix = np.eye(n_features)
    features = np.zeros((n_nodes, n_features))
    for k in range(n_communities):
        nodes_in_community = np.where(communities == k)[0]
        features[nodes_in_community] = np.random.multivariate_normal(node_feature_means[k], feature_cov_matrix,\
                                                                     len(nodes_in_community))

    # Compute community membership probabilities based on node features
    community_membership_probs = softmax(features @ node_feature_means.T, axis=1)

    # Generate edges based on community membership probabilities
    adjacency_matrix = np.zeros((n_nodes, n_nodes))
    for i in range(n_nodes):
        for j in range(i, n_nodes):
            if i == j:
                continue
            community_i = communities[i]
            community_j = communities[j]
            edge_prob = edge_prob_matrix[community_i, community_j] * community_membership_probs[i, community_j] * community_membership_probs[j, community_i]
            adjacency_matrix[i, j] = adjacency_matrix[j, i] = np.random.binomial(1, edge_prob)

    labels = tf.keras.utils.to_categorical(communities)
    adjacency_matrix = sparse.csr_matrix(adjacency_matrix)
    return Graph(x=features, a=adjacency_matrix, y=labels)

    #return adjacency_matrix, features, communities

# %% [markdown]
# ### Class for generating synthetic datasets

# %%
class SyntheticDataset(Dataset):
    def __init__(self, graphs=None, **kwargs):
        self.graphs = graphs
        super().__init__(**kwargs)

    def read(self):
        return self.graphs

# %% [markdown]
# ### Generating graphs

# %%
n_graphs = 2
n_nodes = 100
n_features = 2
n_classes = 2
# Probability matrix for edges between communities
edge_prob_matrix = np.array([
    [0.5, 0.5],
    [0.5, 0.5]
])

# Node feature means for each community
node_feature_means = np.array([
    [2, 1], #, 0, 0, 0],
    [1, 2] #, 0, 0, 0]
])


graphs = [generate_synthetic_graph_csbm(n_nodes, n_classes, n_features, edge_prob_matrix, node_feature_means, feature_cov_matrix=None) for _ in range(n_graphs)]

# %%
for G in graphs:
    nxG = nx.from_numpy_array(G.a)
    labels = np.argmax(G.y,axis=1)
    plot_graph(nxG,labels)

# %%
train_graphs, test_graphs = train_test_split(graphs, test_size=0.5, random_state=42)
train_dataset = SyntheticDataset(train_graphs)
test_dataset = SyntheticDataset(test_graphs)

# %%
from spektral.data import BatchLoader,DisjointLoader,SingleLoader
batch_size = 1

# Create data loaders for training and testing data
#train_loader = BatchLoader(train_dataset, batch_size=batch_size)
#test_loader = BatchLoader(test_dataset, batch_size=batch_size)

train_loader = SingleLoader(train_dataset)
test_loader = SingleLoader(test_dataset)

# %%
model = GCN(n_labels=n_classes,channels=16,l2_reg=1.0000,dropout_rate=0)

# %%
# Compile the model
model.compile(optimizer=Adam(learning_rate=0.01), loss="binary_crossentropy", metrics=["accuracy"])

# Define early stopping to prevent overfitting
es_callback = EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True)

# Train the model
history = model.fit(
    train_loader.load(),
    steps_per_epoch=train_loader.steps_per_epoch,
    epochs=100,
    validation_data=test_loader.load(),
    validation_steps=test_loader.steps_per_epoch#,
    #callbacks=[es_callback],
)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 96.5946 - accuracy: 0.5200 - val_loss: 90.1017 - val_accuracy: 0.4900
# Epoch 2/100
# 1/1 [==============================] - 0s 13ms/step - loss: 84.3403 - accuracy: 0.5200 - val_loss: 79.2374 - val_accuracy: 0.4900
# Epoch 3/100
# 1/1 [==============================] - 0s 13ms/step - loss: 72.4162 - accuracy: 0.5200 - val_loss: 68.7063 - val_accuracy: 0.4900
# Epoch 4/100
# 1/1 [==============================] - 0s 14ms/step - loss: 60.7935 - accuracy: 0.5200 - val_loss: 58.3304 - val_accuracy: 0.4900
# Epoch 5/100
# 1/1 [==============================] - 0s 13ms/step - loss: 49.4043 - accuracy: 0.5200 - val_loss: 48.1117 - val_accuracy: 0.4900
# Epoch 6/100
# 1/1 [==============================] - 0s 13ms/step - loss: 38.2888 - accuracy: 0.5200 - val_loss: 38.0974 - val_accuracy: 0.4900
# Epoch 7/100
# 1/1 [==============================] - 0s 13ms/step - loss: 27.8333 - accuracy: 0.5200 - val_loss: 28.4790 - val_accuracy: 0.4900
# Epoch 8/100
# 1/1 [==============================] - 0s 13ms/step - loss: 21.7728 - accuracy: 0.5200 - val_loss: 21.3987 - val_accuracy: 0.4900
# Epoch 9/100
# 1/1 [==============================] - 0s 12ms/step - loss: 17.4821 - accuracy: 0.5200 - val_loss: 16.0308 - val_accuracy: 0.4900
# Epoch 10/100
# 1/1 [==============================] - 0s 12ms/step - loss: 13.6578 - accuracy: 0.5200 - val_loss: 11.4829 - val_accuracy: 0.5200
# Epoch 11/100
# 1/1 [==============================] - 0s 12ms/step - loss: 10.1273 - accuracy: 0.5200 - val_loss: 7.3183 - val_accuracy: 0.7400
# Epoch 12/100
# 1/1 [==============================] - 0s 13ms/step - loss: 6.4640 - accuracy: 0.6100 - val_loss: 4.8543 - val_accuracy: 0.8200
# Epoch 13/100
# 1/1 [==============================] - 0s 13ms/step - loss: 5.1764 - accuracy: 0.8900 - val_loss: 6.9998 - val_accuracy: 0.8400
# Epoch 14/100
# 1/1 [==============================] - 0s 13ms/step - loss: 7.8952 - accuracy: 0.8900 - val_loss: 8.7145 - val_accuracy: 0.8500
# Epoch 15/100
# 1/1 [==============================] - 0s 12ms/step - loss: 9.2067 - accuracy: 0.9300 - val_loss: 9.5224 - val_accuracy: 0.8700
# Epoch 16/100
# 1/1 [==============================] - 0s 11ms/step - loss: 9.4509 - accuracy: 0.9400 - val_loss: 9.6231 - val_accuracy: 0.8700
# Epoch 17/100
# 1/1 [==============================] - 0s 13ms/step - loss: 8.8642 - accuracy: 0.9400 - val_loss: 9.1469 - val_accuracy: 0.8700
# Epoch 18/100
# 1/1 [==============================] - 0s 13ms/step - loss: 7.6165 - accuracy: 0.9400 - val_loss: 8.1990 - val_accuracy: 0.8700
# Epoch 19/100
# 1/1 [==============================] - 0s 12ms/step - loss: 5.8731 - accuracy: 0.9400 - val_loss: 7.0508 - val_accuracy: 0.8700
# Epoch 20/100
# 1/1 [==============================] - 0s 14ms/step - loss: 4.5922 - accuracy: 0.9400 - val_loss: 6.4542 - val_accuracy: 0.8800
# Epoch 21/100
# 1/1 [==============================] - 0s 13ms/step - loss: 4.1146 - accuracy: 0.9400 - val_loss: 6.1818 - val_accuracy: 0.8700
# Epoch 22/100
# 1/1 [==============================] - 0s 14ms/step - loss: 3.9351 - accuracy: 0.9400 - val_loss: 6.0512 - val_accuracy: 0.8700
# Epoch 23/100
# 1/1 [==============================] - 0s 13ms/step - loss: 3.8399 - accuracy: 0.9400 - val_loss: 6.0189 - val_accuracy: 0.8800
# Epoch 24/100
# 1/1 [==============================] - 0s 14ms/step - loss: 3.7826 - accuracy: 0.9400 - val_loss: 6.0214 - val_accuracy: 0.8800
# Epoch 25/100
# 1/1 [==============================] - 0s 13ms/step - loss: 3.7398 - accuracy: 0.9400 - val_loss: 6.0551 - val_accuracy: 0.8800
# Epoch 26/100
# 1/1 [==============================] - 0s 13ms/step - loss: 3.7057 - accuracy: 0.9400 - val_loss: 6.1235 - val_accuracy: 0.8800
# Epoch 27/100
# 1/1 [==============================] - 0s 14ms/step - loss: 3.6818 - accuracy: 0.9400 - val_loss: 6.2068 - val_accuracy: 0.8800
# Epoch 28/100
# 1/1 [==============================] - 0s 13ms/step - loss: 3.6662 - accuracy: 0.9400 - val_loss: 6.2908 - val_accuracy: 0.8800
# Epoch 29/100
# 1/1 [==============================] - 0s 12ms/step - loss: 3.6512 - accuracy: 0.9400 - val_loss: 6.3745 - val_accuracy: 0.8800
# Epoch 30/100
# 1/1 [==============================] - 0s 12ms/step - loss: 3.6359 - accuracy: 0.9400 - val_loss: 6.4569 - val_accuracy: 0.8800
# Epoch 31/100
# 1/1 [==============================] - 0s 13ms/step - loss: 3.6201 - accuracy: 0.9400 - val_loss: 6.5374 - val_accuracy: 0.8800
# Epoch 32/100
# 1/1 [==============================] - 0s 14ms/step - loss: 3.6039 - accuracy: 0.9400 - val_loss: 6.6157 - val_accuracy: 0.8800
# Epoch 33/100
# 1/1 [==============================] - 0s 13ms/step - loss: 3.5874 - accuracy: 0.9400 - val_loss: 6.6902 - val_accuracy: 0.8800
# Epoch 34/100
# 1/1 [==============================] - 0s 12ms/step - loss: 3.5701 - accuracy: 0.9400 - val_loss: 6.7591 - val_accuracy: 0.8800
# Epoch 35/100
# 1/1 [==============================] - 0s 12ms/step - loss: 3.5518 - accuracy: 0.9400 - val_loss: 6.8215 - val_accuracy: 0.8800
# Epoch 36/100
# 1/1 [==============================] - 0s 13ms/step - loss: 3.5327 - accuracy: 0.9400 - val_loss: 6.8775 - val_accuracy: 0.8800
# Epoch 37/100
# 1/1 [==============================] - 0s 13ms/step - loss: 3.5133 - accuracy: 0.9400 - val_loss: 6.9296 - val_accuracy: 0.8700
# Epoch 38/100
# 1/1 [==============================] - 0s 13ms/step - loss: 3.4934 - accuracy: 0.9400 - val_loss: 6.9786 - val_accuracy: 0.8700
# Epoch 39/100
# 1/1 [==============================] - 0s 12ms/step - loss: 3.4729 - accuracy: 0.9400 - val_loss: 7.0236 - val_accuracy: 0.8700
# Epoch 40/100
# 1/1 [==============================] - 0s 13ms/step - loss: 3.4515 - accuracy: 0.9500 - val_loss: 7.0647 - val_accuracy: 0.8700
# Epoch 41/100
# 1/1 [==============================] - 0s 12ms/step - loss: 3.4291 - accuracy: 0.9500 - val_loss: 7.1029 - val_accuracy: 0.8700
# Epoch 42/100
# 1/1 [==============================] - 0s 12ms/step - loss: 3.4059 - accuracy: 0.9500 - val_loss: 7.1400 - val_accuracy: 0.8800
# Epoch 43/100
# 1/1 [==============================] - 0s 12ms/step - loss: 3.3819 - accuracy: 0.9500 - val_loss: 7.1769 - val_accuracy: 0.8800
# Epoch 44/100
# 1/1 [==============================] - 0s 13ms/step - loss: 3.3575 - accuracy: 0.9500 - val_loss: 7.2140 - val_accuracy: 0.8800
# Epoch 45/100
# 1/1 [==============================] - 0s 13ms/step - loss: 3.3327 - accuracy: 0.9500 - val_loss: 7.2547 - val_accuracy: 0.8800
# Epoch 46/100
# 1/1 [==============================] - 0s 12ms/step - loss: 3.3072 - accuracy: 0.9500 - val_loss: 7.2936 - val_accuracy: 0.8800
# Epoch 47/100
# 1/1 [==============================] - 0s 13ms/step - loss: 3.2815 - accuracy: 0.9500 - val_loss: 7.3301 - val_accuracy: 0.8700
# Epoch 48/100
# 1/1 [==============================] - 0s 12ms/step - loss: 3.2557 - accuracy: 0.9500 - val_loss: 7.3649 - val_accuracy: 0.8700
# Epoch 49/100
# 1/1 [==============================] - 0s 13ms/step - loss: 3.2298 - accuracy: 0.9500 - val_loss: 7.3983 - val_accuracy: 0.8700
# Epoch 50/100
# 1/1 [==============================] - 0s 14ms/step - loss: 3.2037 - accuracy: 0.9600 - val_loss: 7.4303 - val_accuracy: 0.8700
# Epoch 51/100
# 1/1 [==============================] - 0s 12ms/step - loss: 3.1776 - accuracy: 0.9600 - val_loss: 7.4604 - val_accuracy: 0.8700
# Epoch 52/100
# 1/1 [==============================] - 0s 14ms/step - loss: 3.1516 - accuracy: 0.9600 - val_loss: 7.4890 - val_accuracy: 0.8700
# Epoch 53/100
# 1/1 [==============================] - 0s 13ms/step - loss: 3.1257 - accuracy: 0.9600 - val_loss: 7.5155 - val_accuracy: 0.8600
# Epoch 54/100
# 1/1 [==============================] - 0s 12ms/step - loss: 3.0998 - accuracy: 0.9600 - val_loss: 7.5399 - val_accuracy: 0.8600
# Epoch 55/100
# 1/1 [==============================] - 0s 11ms/step - loss: 3.0740 - accuracy: 0.9600 - val_loss: 7.5621 - val_accuracy: 0.8600
# Epoch 56/100
# 1/1 [==============================] - 0s 11ms/step - loss: 3.0485 - accuracy: 0.9600 - val_loss: 7.5813 - val_accuracy: 0.8600
# Epoch 57/100
# 1/1 [==============================] - 0s 12ms/step - loss: 3.0232 - accuracy: 0.9600 - val_loss: 7.5982 - val_accuracy: 0.8600
# Epoch 58/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.9982 - accuracy: 0.9600 - val_loss: 7.6131 - val_accuracy: 0.8600
# Epoch 59/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.9734 - accuracy: 0.9600 - val_loss: 7.6259 - val_accuracy: 0.8600
# Epoch 60/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.9489 - accuracy: 0.9600 - val_loss: 7.6372 - val_accuracy: 0.8400
# Epoch 61/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.9249 - accuracy: 0.9600 - val_loss: 7.6478 - val_accuracy: 0.8400
# Epoch 62/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.9013 - accuracy: 0.9600 - val_loss: 7.6576 - val_accuracy: 0.8400
# Epoch 63/100
# 1/1 [==============================] - 0s 14ms/step - loss: 2.8783 - accuracy: 0.9600 - val_loss: 7.6662 - val_accuracy: 0.8400
# Epoch 64/100
# 1/1 [==============================] - 0s 11ms/step - loss: 2.8558 - accuracy: 0.9600 - val_loss: 7.6726 - val_accuracy: 0.8400
# Epoch 65/100
# 1/1 [==============================] - 0s 14ms/step - loss: 2.8338 - accuracy: 0.9600 - val_loss: 7.6757 - val_accuracy: 0.8300
# Epoch 66/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.8124 - accuracy: 0.9600 - val_loss: 7.6754 - val_accuracy: 0.8300
# Epoch 67/100
# 1/1 [==============================] - 0s 14ms/step - loss: 2.7915 - accuracy: 0.9600 - val_loss: 7.6709 - val_accuracy: 0.8200
# Epoch 68/100
# 1/1 [==============================] - 0s 11ms/step - loss: 2.7710 - accuracy: 0.9600 - val_loss: 7.6622 - val_accuracy: 0.8200
# Epoch 69/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.7508 - accuracy: 0.9600 - val_loss: 7.6479 - val_accuracy: 0.8200
# Epoch 70/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.7313 - accuracy: 0.9600 - val_loss: 7.6311 - val_accuracy: 0.8100
# Epoch 71/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.7115 - accuracy: 0.9600 - val_loss: 7.6085 - val_accuracy: 0.8000
# Epoch 72/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.6921 - accuracy: 0.9600 - val_loss: 7.5807 - val_accuracy: 0.8000
# Epoch 73/100
# 1/1 [==============================] - 0s 14ms/step - loss: 2.6729 - accuracy: 0.9600 - val_loss: 7.5366 - val_accuracy: 0.8000
# Epoch 74/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.6535 - accuracy: 0.9600 - val_loss: 7.4764 - val_accuracy: 0.8000
# Epoch 75/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.6339 - accuracy: 0.9600 - val_loss: 7.4060 - val_accuracy: 0.8000
# Epoch 76/100
# 1/1 [==============================] - 0s 11ms/step - loss: 2.6145 - accuracy: 0.9600 - val_loss: 7.3291 - val_accuracy: 0.8000
# Epoch 77/100
# 1/1 [==============================] - 0s 14ms/step - loss: 2.5952 - accuracy: 0.9600 - val_loss: 7.2487 - val_accuracy: 0.8000
# Epoch 78/100
# 1/1 [==============================] - 0s 14ms/step - loss: 2.5762 - accuracy: 0.9600 - val_loss: 7.1669 - val_accuracy: 0.8000
# Epoch 79/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.5573 - accuracy: 0.9600 - val_loss: 7.0858 - val_accuracy: 0.8000
# Epoch 80/100
# 1/1 [==============================] - 0s 14ms/step - loss: 2.5386 - accuracy: 0.9600 - val_loss: 7.0075 - val_accuracy: 0.8000
# Epoch 81/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.5201 - accuracy: 0.9600 - val_loss: 6.9347 - val_accuracy: 0.8000
# Epoch 82/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.5017 - accuracy: 0.9600 - val_loss: 6.8699 - val_accuracy: 0.8000
# Epoch 83/100
# 1/1 [==============================] - 0s 15ms/step - loss: 2.4836 - accuracy: 0.9600 - val_loss: 6.8165 - val_accuracy: 0.8000
# Epoch 84/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.4656 - accuracy: 0.9600 - val_loss: 6.7759 - val_accuracy: 0.8000
# Epoch 85/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.4477 - accuracy: 0.9600 - val_loss: 6.7481 - val_accuracy: 0.7900
# Epoch 86/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.4300 - accuracy: 0.9600 - val_loss: 6.7309 - val_accuracy: 0.7900
# Epoch 87/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.4124 - accuracy: 0.9600 - val_loss: 6.7220 - val_accuracy: 0.7900
# Epoch 88/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.3950 - accuracy: 0.9600 - val_loss: 6.7180 - val_accuracy: 0.7900
# Epoch 89/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.3777 - accuracy: 0.9600 - val_loss: 6.7147 - val_accuracy: 0.7900
# Epoch 90/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.3607 - accuracy: 0.9600 - val_loss: 6.7084 - val_accuracy: 0.7900
# Epoch 91/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.3437 - accuracy: 0.9500 - val_loss: 6.6962 - val_accuracy: 0.7900
# Epoch 92/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.3268 - accuracy: 0.9500 - val_loss: 6.6767 - val_accuracy: 0.7900
# Epoch 93/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.3100 - accuracy: 0.9500 - val_loss: 6.6500 - val_accuracy: 0.7900
# Epoch 94/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.2932 - accuracy: 0.9500 - val_loss: 6.6171 - val_accuracy: 0.7900
# Epoch 95/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.2764 - accuracy: 0.9500 - val_loss: 6.5793 - val_accuracy: 0.7900
# Epoch 96/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.2595 - accuracy: 0.9500 - val_loss: 6.5373 - val_accuracy: 0.7900
# Epoch 97/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.2426 - accuracy: 0.9500 - val_loss: 6.4921 - val_accuracy: 0.7900
# Epoch 98/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.2258 - accuracy: 0.9500 - val_loss: 6.4442 - val_accuracy: 0.7900
# Epoch 99/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.2091 - accuracy: 0.9500 - val_loss: 6.3938 - val_accuracy: 0.7900
# Epoch 100/100
# 1/1 [==============================] - 0s 11ms/step - loss: 2.1923 - accuracy: 0.9500 - val_loss: 6.3413 - val_accuracy: 0.7900

# %%
import pandas as pd
res=pd.DataFrame(history.history)

# Add row index as a new column
res.reset_index(inplace=True)

# Rename the new column to 'row_id'
res.rename(columns={'index': 'epoch'}, inplace=True)
res
# Out:
#     epoch       loss  accuracy   val_loss  val_accuracy
# 0       0  96.594559      0.52  90.101746          0.49
# 1       1  84.340309      0.52  79.237373          0.49
# 2       2  72.416191      0.52  68.706284          0.49
# 3       3  60.793545      0.52  58.330410          0.49
# 4       4  49.404320      0.52  48.111683          0.49
# ..    ...        ...       ...        ...           ...
# 95     95   2.259496      0.95   6.537336          0.79
# 96     96   2.242632      0.95   6.492149          0.79
# 97     97   2.225807      0.95   6.444174          0.79
# 98     98   2.209056      0.95   6.393811          0.79
# 99     99   2.192328      0.95   6.341303          0.79
#
# [100 rows x 5 columns]

# %%
history.history['accuracy']

import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="whitegrid")
line1 = sns.lineplot(x="epoch", y='loss', data=res, label='Training Loss')
line2 = sns.lineplot(x="epoch", y='val_loss', data=res, label='Test Loss')


# Add points to each observation
scatter1 = sns.scatterplot(x="epoch", y='loss', data=res, marker='o', color='skyblue')
scatter2 = sns.scatterplot(x="epoch", y='val_loss', data=res, marker='o', color='orange')

# Change the y-axis label
plt.ylabel("Loss Value")

# Create a legend for the lines
plt.legend()

# Show the plot
plt.show()

# %%
sns.set_theme(style="whitegrid")
line1 = sns.lineplot(x="epoch", y="accuracy", data=res, label='Training Accuracy')
line2 = sns.lineplot(x="epoch", y="val_accuracy", data=res, label='Test Accuracy')

# Add points to each observation
scatter1 = sns.scatterplot(x="epoch", y="accuracy", data=res, marker='o', color='skyblue')
scatter2 = sns.scatterplot(x="epoch", y="val_accuracy", data=res, marker='o', color='orange')

# Change the y-axis label
plt.ylabel("Accuracy Value")

# Create a legend for the lines
plt.legend()

# Show the plot
plt.show()

# %%
predictions = []
targets = []
step = 0
while step < test_loader.steps_per_epoch:
        step += 1
        inputs, target = test_loader.__next__()
        pred = model(inputs, training=False)
        predictions.append(pred)
        targets.append(target)
    
predictions = np.vstack(predictions)
    
targets = np.vstack(targets)
# Post-process the predictions if necessary (e.g., convert probabilities to class labels)
predicted_values = np.argmax(predictions, axis=1)
true_labels = np.argmax(targets,axis =1 )

# %%
from sklearn.metrics import confusion_matrix,roc_auc_score,accuracy_score
conf_mat = confusion_matrix(predicted_values, true_labels)
print(conf_mat)
# Out:
# [[30  2]
#  [19 49]]

# %%
auc_score = roc_auc_score(true_labels, predicted_values)
accuracy_score = accuracy_score(true_labels, predicted_values)

print("AUC Score:", auc_score)
print("Accuracy Score:", accuracy_score)
# Out:
# AUC Score: 0.786514605842337
# Accuracy Score: 0.79
