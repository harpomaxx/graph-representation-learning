# %%
# !pip install networkx
# Out:
# Requirement already satisfied: networkx in /usr/local/lib/python3.8/dist-packages (3.1)
# WARNING: You are using pip version 20.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      |████████████████████████████████| 293 kB 928 kB/s eta 0:00:01
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /usr/local/lib/python3.8/dist-packages (from seaborn) (3.6.2)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.8/dist-packages (from seaborn) (1.5.3)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /usr/local/lib/python3.8/dist-packages (from seaborn) (1.23.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.3.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.14.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.12.2
# WARNING: You are using pip version 20.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import networkx as nx

import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

from spektral.data import Dataset, Graph
from spektral.layers import GraphSageConv
from spektral.utils import normalized_adjacency
from spektral.models.gcn import GCN 

from scipy import sparse
from scipy.special import softmax

from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Function to plotting a graph

# %%
def plot_graph(G, communities=None):
    pos = nx.spring_layout(G, seed=42)
    
    if communities is not None:
        # Assign colors to nodes based on their communities
        colors = ['orange' if community == 0 else 'skyblue' for community in communities]
    else:
        colors = 'red'

    nx.draw(G, pos, node_color=colors, with_labels=True)
    plt.show()

# %% [markdown]
# ## CSBM Generation - Caso base

# %%
def generate_synthetic_graph_csbm(n_nodes, n_communities, n_features, edge_prob_matrix, node_feature_means,\
                                  feature_cov_matrix=None):
    # Assign nodes to communities
    communities = np.random.randint(0, n_communities, n_nodes)

    # Generate node features
    if feature_cov_matrix is None:
        feature_cov_matrix = np.eye(n_features)
    features = np.zeros((n_nodes, n_features))
    for k in range(n_communities):
        nodes_in_community = np.where(communities == k)[0]
        features[nodes_in_community] = np.random.multivariate_normal(node_feature_means[k], feature_cov_matrix,\
                                                                     len(nodes_in_community))

    # Compute community membership probabilities based on node features
    community_membership_probs = softmax(features @ node_feature_means.T, axis=1)

    # Generate edges based on community membership probabilities
    adjacency_matrix = np.zeros((n_nodes, n_nodes))
    for i in range(n_nodes):
        for j in range(i, n_nodes):
            if i == j:
                continue
            community_i = communities[i]
            community_j = communities[j]
            edge_prob = edge_prob_matrix[community_i, community_j] * community_membership_probs[i, community_j] * community_membership_probs[j, community_i]
            adjacency_matrix[i, j] = adjacency_matrix[j, i] = np.random.binomial(1, edge_prob)

    labels = tf.keras.utils.to_categorical(communities)
    adjacency_matrix = sparse.csr_matrix(adjacency_matrix)
    return Graph(x=features, a=adjacency_matrix, y=labels)

    #return adjacency_matrix, features, communities

# %% [markdown]
# ### Class for generating synthetic datasets

# %%
class SyntheticDataset(Dataset):
    def __init__(self, graphs=None, **kwargs):
        self.graphs = graphs
        super().__init__(**kwargs)

    def read(self):
        return self.graphs

# %% [markdown]
# ### Generating graphs

# %%
n_graphs = 2
n_nodes = 100
n_features = 2
n_classes = 2
# Probability matrix for edges between communities
edge_prob_matrix = np.array([
    [0.5, 0.5],
    [0.5, 0.5]
])

# Node feature means for each community
node_feature_means = np.array([
    [1, 1], #, 0, 0, 0],
    [1, 1] #, 0, 0, 0]
])


graphs = [generate_synthetic_graph_csbm(n_nodes, n_classes, n_features, edge_prob_matrix, node_feature_means, feature_cov_matrix=None) for _ in range(n_graphs)]

# %%
for G in graphs:
    nxG = nx.from_numpy_array(G.a)
    labels = np.argmax(G.y,axis=1)
    plot_graph(nxG,labels)

# %%
train_graphs, test_graphs = train_test_split(graphs, test_size=0.5, random_state=42)
train_dataset = SyntheticDataset(train_graphs)
test_dataset = SyntheticDataset(test_graphs)

# %%
from spektral.data import BatchLoader,DisjointLoader,SingleLoader
batch_size = 1

# Create data loaders for training and testing data
#train_loader = BatchLoader(train_dataset, batch_size=batch_size)
#test_loader = BatchLoader(test_dataset, batch_size=batch_size)

train_loader = SingleLoader(train_dataset)
test_loader = SingleLoader(test_dataset)

# %%
model = GCN(n_labels=n_classes,channels=16,l2_reg=1.0000,dropout_rate=0)

# %%
# Compile the model
model.compile(optimizer=Adam(learning_rate=0.01), loss="binary_crossentropy", metrics=["accuracy"])

# Define early stopping to prevent overfitting
es_callback = EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True)

# Train the model
history = model.fit(
    train_loader.load(),
    steps_per_epoch=train_loader.steps_per_epoch,
    epochs=100,
    validation_data=test_loader.load(),
    validation_steps=test_loader.steps_per_epoch#,
    #callbacks=[es_callback],
)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 61.1553 - accuracy: 0.4800 - val_loss: 53.4534 - val_accuracy: 0.5300
# Epoch 2/100
# 1/1 [==============================] - 0s 14ms/step - loss: 56.3537 - accuracy: 0.4800 - val_loss: 48.8346 - val_accuracy: 0.5300
# Epoch 3/100
# 1/1 [==============================] - 0s 12ms/step - loss: 51.5760 - accuracy: 0.4800 - val_loss: 44.1781 - val_accuracy: 0.5300
# Epoch 4/100
# 1/1 [==============================] - 0s 13ms/step - loss: 46.7822 - accuracy: 0.4800 - val_loss: 39.4901 - val_accuracy: 0.5300
# Epoch 5/100
# 1/1 [==============================] - 0s 13ms/step - loss: 41.9118 - accuracy: 0.4800 - val_loss: 34.7644 - val_accuracy: 0.5300
# Epoch 6/100
# 1/1 [==============================] - 0s 14ms/step - loss: 36.9412 - accuracy: 0.4800 - val_loss: 29.9743 - val_accuracy: 0.5300
# Epoch 7/100
# 1/1 [==============================] - 0s 12ms/step - loss: 31.8590 - accuracy: 0.4800 - val_loss: 25.0409 - val_accuracy: 0.5300
# Epoch 8/100
# 1/1 [==============================] - 0s 12ms/step - loss: 27.0912 - accuracy: 0.4800 - val_loss: 19.9855 - val_accuracy: 0.5300
# Epoch 9/100
# 1/1 [==============================] - 0s 12ms/step - loss:
100
# 1/1 [==============================] - 0s 12ms/step - loss: 6.7372 - accuracy: 0.5000 - val_loss: 9.1733 - val_accuracy: 0.4700
# Epoch 32/100
# 1/1 [==============================] - 0s 13ms/step - loss: 6.0839 - accuracy: 0.4800 - val_loss: 10.1186 - val_accuracy: 0.4700
# Epoch 33/100
# 1/1 [==============================] - 0s 13ms/step - loss: 5.3852 - accuracy: 0.4600 - val_loss: 11.0895 - val_accuracy: 0.4700
# Epoch 34/100
# 1/1 [==============================] - 0s 12ms/step - loss: 5.0594 - accuracy: 0.4300 - val_loss: 11.8461 - val_accuracy: 0.4700
# Epoch 35/100
# 1/1 [==============================] - 0s 13ms/step - loss: 5.2230 - accuracy: 0.4200 - val_loss: 12.1942 - val_accuracy: 0.4700
# Epoch 36/100
# 1/1 [==============================] - 0s 12ms/step - loss: 5.5325 - accuracy: 0.4400 - val_loss: 12.0973 - val_accuracy: 0.4700
# Epoch 37/100
# 1/1 [==============================] - 0s 12ms/step - loss: 5.6740 - accuracy: 0.4400 - val_loss: 11.6469 - val_accuracy: 0.4700
# Epoch 38/100
# 1/1 [==============================] - 0s 13ms/step - loss: 5.5573 - accuracy: 0.4300 - val_loss: 10.9590 - val_accuracy: 0.4700
# Epoch 39/100
# 1/1 [==============================] - 0s 12ms/step - loss: 5.2287 - accuracy: 0.4200 - val_loss: 10.1459 - val_accuracy: 0.4700
# Epoch 40/100
# 1/1 [==============================] - 0s 13ms/step - loss: 4.8315 - accuracy: 0.4500 - val_loss: 9.3177 - val_accuracy: 0.4700
# Epoch 41/100
# 1/1 [==============================] - 0s 14ms/step - loss: 4.5440 - accuracy: 0.4100 - val_loss: 8.5694 - val_accuracy: 0.4700
# Epoch 42/100
# 1/1 [==============================] - 0s 12ms/step - loss: 4.5031 - accuracy: 0.4700 - val_loss: 7.9877 - val_accuracy: 0.4700
# Epoch 43/100
# 1/1 [==============================] - 0s 13ms/step - loss: 4.6421 - accuracy: 0.4700 - val_loss: 7.6230 - val_accuracy: 0.4700
# Epoch 44/100
# 1/1 [==============================] - 0s 13ms/step - loss: 4.7561 - accuracy: 0.4500 - val_loss: 7.4648 - val_accuracy: 0.4700
# Epoch 45/100
# 1/1 [==============================] - 0s 13ms/step - loss: 4.6992 - accuracy: 0.4500 - val_loss: 7.4794 - val_accuracy: 0.4700
# Epoch 46/100
# 1/1 [==============================] - 0s 12ms/step - loss: 4.4776 - accuracy: 0.4700 - val_loss: 7.6260 - val_accuracy: 0.4700
# Epoch 47/100
# 1/1 [==============================] - 0s 12ms/step - loss: 4.2145 - accuracy: 0.4600 - val_loss: 7.8397 - val_accuracy: 0.4700
# Epoch 48/100
# 1/1 [==============================] - 0s 13ms/step - loss: 4.0584 - accuracy: 0.4000 - val_loss: 8.0512 - val_accuracy: 0.4700
# Epoch 49/100
# 1/1 [==============================] - 0s 11ms/step - loss: 4.0446 - accuracy: 0.4100 - val_loss: 8.1947 - val_accuracy: 0.4700
# Epoch 50/100
# 1/1 [==============================] - 0s 13ms/step - loss: 4.0875 - accuracy: 0.4500 - val_loss: 8.2192 - val_accuracy: 0.4700
# Epoch 51/100
# 1/1 [==============================] - 0s 12ms/step - loss: 4.0807 - accuracy: 0.4400 - val_loss: 8.0908 - val_accuracy: 0.4700
# Epoch 52/100
# 1/1 [==============================] - 0s 12ms/step - loss: 3.9933 - accuracy: 0.4300 - val_loss: 7.7902 - val_accuracy: 0.4700
# Epoch 53/100
# 1/1 [==============================] - 0s 12ms/step - loss: 3.8517 - accuracy: 0.4300 - val_loss: 7.3297 - val_accuracy: 0.4700
# Epoch 54/100
# 1/1 [==============================] - 0s 12ms/step - loss: 3.7013 - accuracy: 0.4500 - val_loss: 7.0769 - val_accuracy: 0.4700
# Epoch 55/100
# 1/1 [==============================] - 0s 13ms/step - loss: 3.6383 - accuracy: 0.4500 - val_loss: 6.0811 - val_accuracy: 0.4700
# Epoch 56/100
# 1/1 [==============================] - 0s 12ms/step - loss: 3.5622 - accuracy: 0.4500 - val_loss: 5.5372 - val_accuracy: 0.4700
# Epoch 57/100
# 1/1 [==============================] - 0s 12ms/step - loss: 3.5898 - accuracy: 0.4600 - val_loss: 5.2304 - val_accuracy: 0.4700
# Epoch 58/100
# 1/1 [==============================] - 0s 12ms/step - loss: 3.5717 - accuracy: 0.4600 - val_loss: 5.1721 - val_accuracy: 0.4700
# Epoch 59/100
# 1/1 [==============================] - 0s 13ms/step - loss: 3.4495 - accuracy: 0.4500 - val_loss: 5.3048 - val_accuracy: 0.4700
# Epoch 60/100
# 1/1 [==============================] - 0s 12ms/step - loss: 3.2781 - accuracy: 0.4400 - val_loss: 5.5365 - val_accuracy: 0.4700
# Epoch 61/100
# 1/1 [==============================] - 0s 13ms/step - loss: 3.2507 - accuracy: 0.4500 - val_loss: 5.5256 - val_accuracy: 0.4700
# Epoch 62/100
# 1/1 [==============================] - 0s 12ms/step - loss: 3.1797 - accuracy: 0.4500 - val_loss: 5.4796 - val_accuracy: 0.4700
# Epoch 63/100
# 1/1 [==============================] - 0s 12ms/step - loss: 3.2056 - accuracy: 0.4600 - val_loss: 5.3785 - val_accuracy: 0.4700
# Epoch 64/100
# 1/1 [==============================] - 0s 13ms/step - loss: 3.1784 - accuracy: 0.4600 - val_loss: 5.1402 - val_accuracy: 0.4700
# Epoch 65/100
# 1/1 [==============================] - 0s 12ms/step - loss: 3.0645 - accuracy: 0.4600 - val_loss: 4.8380 - val_accuracy: 0.4700
# Epoch 66/100
# 1/1 [==============================] - 0s 13ms/step - loss: 3.0071 - accuracy: 0.4400 - val_loss: 4.5266 - val_accuracy: 0.4700
# Epoch 67/100
# 1/1 [==============================] - 0s 11ms/step - loss: 2.9923 - accuracy: 0.4300 - val_loss: 4.3024 - val_accuracy: 0.4700
# Epoch 68/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.9581 - accuracy: 0.4600 - val_loss: 4.2837 - val_accuracy: 0.4700
# Epoch 69/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.9287 - accuracy: 0.4400 - val_loss: 4.3730 - val_accuracy: 0.4700
# Epoch 70/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.8533 - accuracy: 0.4500 - val_loss: 4.4659 - val_accuracy: 0.4700
# Epoch 71/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.8427 - accuracy: 0.4700 - val_loss: 4.6176 - val_accuracy: 0.4700
# Epoch 72/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.8061 - accuracy: 0.4700 - val_loss: 4.6966 - val_accuracy: 0.4700
# Epoch 73/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.8188 - accuracy: 0.4600 - val_loss: 4.4776 - val_accuracy: 0.4700
# Epoch 74/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.7458 - accuracy: 0.4700 - val_loss: 4.1685 - val_accuracy: 0.4700
# Epoch 75/100
# 1/1 [==============================] - 0s 14ms/step - loss: 2.7316 - accuracy: 0.4900 - val_loss: 3.9942 - val_accuracy: 0.4700
# Epoch 76/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.6972 - accuracy: 0.4700 - val_loss: 3.9465 - val_accuracy: 0.4800
# Epoch 77/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.7007 - accuracy: 0.5200 - val_loss: 3.9164 - val_accuracy: 0.4700
# Epoch 78/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.6433 - accuracy: 0.4600 - val_loss: 3.9435 - val_accuracy: 0.4700
# Epoch 79/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.6267 - accuracy: 0.4900 - val_loss: 4.0222 - val_accuracy: 0.4700
# Epoch 80/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.5990 - accuracy: 0.4700 - val_loss: 4.0163 - val_accuracy: 0.4700
# Epoch 81/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.5881 - accuracy: 0.4700 - val_loss: 3.8145 - val_accuracy: 0.4700
# Epoch 82/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.5421 - accuracy: 0.5000 - val_loss: 3.5541 - val_accuracy: 0.4700
# Epoch 83/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.5242 - accuracy: 0.4900 - val_loss: 3.4089 - val_accuracy: 0.4700
# Epoch 84/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.5058 - accuracy: 0.5300 - val_loss: 3.4022 - val_accuracy: 0.5100
# Epoch 85/100
# 1/1 [==============================] - 0s 14ms/step - loss: 2.4781 - accuracy: 0.5200 - val_loss: 3.4404 - val_accuracy: 0.4900
# Epoch 86/100
# 1/1 [==============================] - 0s 14ms/step - loss: 2.4476 - accuracy: 0.5200 - val_loss: 3.4308 - val_accuracy: 0.4700
# Epoch 87/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.4360 - accuracy: 0.5100 - val_loss: 3.3344 - val_accuracy: 0.4700
# Epoch 88/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.4099 - accuracy: 0.5100 - val_loss: 3.1701 - val_accuracy: 0.4800
# Epoch 89/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.3855 - accuracy: 0.5600 - val_loss: 3.0116 - val_accuracy: 0.4900
# Epoch 90/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.3690 - accuracy: 0.5900 - val_loss: 2.9386 - val_accuracy: 0.4900
# Epoch 91/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.3490 - accuracy: 0.5300 - val_loss: 3.1340 - val_accuracy: 0.5300
# Epoch 92/100
# 1/1 [==============================] - 0s 11ms/step - loss: 2.3602 - accuracy: 0.5300 - val_loss: 2.8445 - val_accuracy: 0.4700
# Epoch 93/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.3550 - accuracy: 0.5100 - val_loss: 2.7707 - val_accuracy: 0.5300
# Epoch 94/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.2964 - accuracy: 0.5500 - val_loss: 2.7498 - val_accuracy: 0.5300
# Epoch 95/100
# 1/1 [==============================] - 0s 14ms/step - loss: 2.3038 - accuracy: 0.4900 - val_loss: 2.6463 - val_accuracy: 0.4700
# Epoch 96/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.2821 - accuracy: 0.5300 - val_loss: 2.6697 - val_accuracy: 0.5000
# Epoch 97/100
# 1/1 [==============================] - 0s 11ms/step - loss: 2.2507 - accuracy: 0.5100 - val_loss: 2.6725 - val_accuracy: 0.5400
# Epoch 98/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.2614 - accuracy: 0.5000 - val_loss: 2.4910 - val_accuracy: 0.5600
# Epoch 99/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.2223 - accuracy: 0.5500 - val_loss: 2.4209 - val_accuracy: 0.5100
# Epoch 100/100
# 1/1 [==============================] - 0s 14ms/step - loss: 2.2250 - accuracy: 0.5400 - val_loss: 2.4826 - val_accuracy: 0.5500

# %%
import pandas as pd
res=pd.DataFrame(history.history)

# Add row index as a new column
res.reset_index(inplace=True)

# Rename the new column to 'row_id'
res.rename(columns={'index': 'epoch'}, inplace=True)
res
# Out:
#     epoch       loss  accuracy   val_loss  val_accuracy
# 0       0  61.155262      0.48  53.453388          0.53
# 1       1  56.353729      0.48  48.834583          0.53
# 2       2  51.575974      0.48  44.178078          0.53
# 3       3  46.782238      0.48  39.490067          0.53
# 4       4  41.911781      0.48  34.764370          0.53
# ..    ...        ...       ...        ...           ...
# 95     95   2.282146      0.53   2.669660          0.50
# 96     96   2.250733      0.51   2.672527          0.54
# 97     97   2.261429      0.50   2.490971          0.56
# 98     98   2.222335      0.55   2.420913          0.51
# 99     99   2.225034      0.54   2.482647          0.55
#
# [100 rows x 5 columns]

# %%
history.history['accuracy']

import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="whitegrid")
line1 = sns.lineplot(x="epoch", y='loss', data=res, label='Training Loss')
line2 = sns.lineplot(x="epoch", y='val_loss', data=res, label='Test Loss')


# Add points to each observation
scatter1 = sns.scatterplot(x="epoch", y='loss', data=res, marker='o', color='skyblue')
scatter2 = sns.scatterplot(x="epoch", y='val_loss', data=res, marker='o', color='orange')

# Change the y-axis label
plt.ylabel("Loss Value")

# Create a legend for the lines
plt.legend()

# Show the plot
plt.show()

# %%
sns.set_theme(style="whitegrid")
line1 = sns.lineplot(x="epoch", y="accuracy", data=res, label='Training Accuracy')
line2 = sns.lineplot(x="epoch", y="val_accuracy", data=res, label='Test Accuracy')

# Add points to each observation
scatter1 = sns.scatterplot(x="epoch", y="accuracy", data=res, marker='o', color='skyblue')
scatter2 = sns.scatterplot(x="epoch", y="val_accuracy", data=res, marker='o', color='orange')

# Change the y-axis label
plt.ylabel("Accuracy Value")

# Create a legend for the lines
plt.legend()

# Show the plot
plt.show()

# %%
predictions = []
targets = []
step = 0
while step < test_loader.steps_per_epoch:
        step += 1
        inputs, target = test_loader.__next__()
        pred = model(inputs, training=False)
        predictions.append(pred)
        targets.append(target)
    
predictions = np.vstack(predictions)
    
targets = np.vstack(targets)
# Post-process the predictions if necessary (e.g., convert probabilities to class labels)
predicted_values = np.argmax(predictions, axis=1)
true_labels = np.argmax(targets,axis =1 )

# %%
from sklearn.metrics import confusion_matrix,roc_auc_score,accuracy_score
conf_mat = confusion_matrix(predicted_values, true_labels)
print(conf_mat)
# Out:
# [[ 2  0]
#  [45 53]]

# %%
auc_score = roc_auc_score(true_labels, predicted_values)
accuracy_score = accuracy_score(true_labels, predicted_values)

print("AUC Score:", auc_score)
print("Accuracy Score:", accuracy_score)
# Out:
# AUC Score: 0.5212765957446808
# Accuracy Score: 0.55
