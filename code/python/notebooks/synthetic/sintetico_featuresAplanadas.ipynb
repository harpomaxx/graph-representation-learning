# %%
# !pip install networkx
# Out:
# Requirement already satisfied: networkx in /usr/local/lib/python3.8/dist-packages (3.1)
# WARNING: You are using pip version 20.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      |████████████████████████████████| 293 kB 928 kB/s eta 0:00:01
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /usr/local/lib/python3.8/dist-packages (from seaborn) (3.6.2)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.8/dist-packages (from seaborn) (1.5.3)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /usr/local/lib/python3.8/dist-packages (from seaborn) (1.23.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.3.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.14.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.12.2
# WARNING: You are using pip version 20.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import networkx as nx

import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

from spektral.data import Dataset, Graph
from spektral.layers import GraphSageConv
from spektral.utils import normalized_adjacency
from spektral.models.gcn import GCN 

from scipy import sparse
from scipy.special import softmax

from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Function to plotting a graph

# %%
def plot_graph(G, communities=None):
    pos = nx.spring_layout(G, seed=42)
    
    if communities is not None:
        # Assign colors to nodes based on their communities
        colors = ['orange' if community == 0 else 'skyblue' for community in communities]
    else:
        colors = 'red'

    nx.draw(G, pos, node_color=colors, with_labels=True)
    plt.show()

# %% [markdown]
# ## CSBM Generation - FEATURES APLANADAS

# %%
def generate_synthetic_graph_csbm(n_nodes, n_communities, n_features, edge_prob_matrix, node_feature_means,\
                                  feature_cov_matrix=None):
    # Assign nodes to communities
    communities = np.random.randint(0, n_communities, n_nodes)

    # Generate node features
    if feature_cov_matrix is None:
        feature_cov_matrix = np.eye(n_features)
    features = np.ones((n_nodes, n_features))
#     features = np.zeros((n_nodes, n_features))
#     for k in range(n_communities):
#         nodes_in_community = np.where(communities == k)[0]
#         features[nodes_in_community] = np.random.multivariate_normal(node_feature_means[k], feature_cov_matrix,\
#                                                                      len(nodes_in_community))

    # Compute community membership probabilities based on node features
    community_membership_probs = softmax(features @ node_feature_means.T, axis=1)

    # Generate edges based on community membership probabilities
    adjacency_matrix = np.zeros((n_nodes, n_nodes))
    for i in range(n_nodes):
        for j in range(i, n_nodes):
            if i == j:
                continue
            community_i = communities[i]
            community_j = communities[j]
            edge_prob = edge_prob_matrix[community_i, community_j] * community_membership_probs[i, community_j] * community_membership_probs[j, community_i]
            adjacency_matrix[i, j] = adjacency_matrix[j, i] = np.random.binomial(1, edge_prob)

    labels = tf.keras.utils.to_categorical(communities)
    adjacency_matrix = sparse.csr_matrix(adjacency_matrix)
    return Graph(x=features, a=adjacency_matrix, y=labels)

    #return adjacency_matrix, features, communities

# %% [markdown]
# ### Class for generating synthetic datasets

# %%
class SyntheticDataset(Dataset):
    def __init__(self, graphs=None, **kwargs):
        self.graphs = graphs
        super().__init__(**kwargs)

    def read(self):
        return self.graphs

# %% [markdown]
# ### Generating graphs

# %%
n_graphs = 2
n_nodes = 100
n_features = 2
n_classes = 2
# Probability matrix for edges between communities
edge_prob_matrix = np.array([
    [0.8, 0.2],
    [0.3, 0.7]
])

# Node feature means for each community
node_feature_means = np.array([
    [1, 1], #, 0, 0, 0],
    [1, 1] #, 0, 0, 0]
])


graphs = [generate_synthetic_graph_csbm(n_nodes, n_classes, n_features, edge_prob_matrix, node_feature_means, feature_cov_matrix=None) for _ in range(n_graphs)]

# %%
for G in graphs:
    nxG = nx.from_numpy_array(G.a)
    labels = np.argmax(G.y,axis=1)
    plot_graph(nxG,labels)

# %%
train_graphs, test_graphs = train_test_split(graphs, test_size=0.5, random_state=42)
train_dataset = SyntheticDataset(train_graphs)
test_dataset = SyntheticDataset(test_graphs)

# %%
from spektral.data import BatchLoader,DisjointLoader,SingleLoader
batch_size = 1

# Create data loaders for training and testing data
#train_loader = BatchLoader(train_dataset, batch_size=batch_size)
#test_loader = BatchLoader(test_dataset, batch_size=batch_size)

train_loader = SingleLoader(train_dataset)
test_loader = SingleLoader(test_dataset)

# %%
model = GCN(n_labels=n_classes,channels=16,l2_reg=1.0000,dropout_rate=0)

# %%
# Compile the model
model.compile(optimizer=Adam(learning_rate=0.01), loss="binary_crossentropy", metrics=["accuracy"])

# Define early stopping to prevent overfitting
es_callback = EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True)

# Train the model
history = model.fit(
    train_loader.load(),
    steps_per_epoch=train_loader.steps_per_epoch,
    epochs=100,
    validation_data=test_loader.load(),
    validation_steps=test_loader.steps_per_epoch#,
    #callbacks=[es_callback],
)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 41.3723 - accuracy: 0.5700 - val_loss: 41.1610 - val_accuracy: 0.5100
# Epoch 2/100
# 1/1 [==============================] - 0s 15ms/step - loss: 36.4539 - accuracy: 0.5700 - val_loss: 36.2509 - val_accuracy: 0.5100
# Epoch 3/100
# 1/1 [==============================] - 0s 13ms/step - loss: 31.6790 - accuracy: 0.5700 - val_loss: 31.5188 - val_accuracy: 0.5100
# Epoch 4/100
# 1/1 [==============================] - 0s 14ms/step - loss: 27.0473 - accuracy: 0.5700 - val_loss: 28.4648 - val_accuracy: 0.5100
# Epoch 5/100
# 1/1 [==============================] - 0s 13ms/step - loss: 24.0422 - accuracy: 0.5700 - val_loss: 26.7418 - val_accuracy: 0.5100
# Epoch 6/100
# 1/1 [==============================] - 0s 14ms/step - loss: 22.5998 - accuracy: 0.5700 - val_loss: 24.2442 - val_accuracy: 0.5100
# Epoch 7/100
# 1/1 [==============================] - 0s 13ms/step - loss: 20.5335 - accuracy: 0.5700 - val_loss: 21.2358 - val_accuracy: 0.5100
# Epoch 8/100
# 1/1 [==============================] - 0s 14ms/step - loss: 18.0517 - accuracy: 0.5700 - val_loss: 17.9491 - val_accuracy: 0.5100
# Epoch 9/100
# 1/1 [==============================] - 0s 12ms/step - loss: 15.3446 - accuracy: 0.5700 - val_loss: 14.5633 - val_accuracy: 0.5100
# Epoch 10/100
# 1/1 [==============================] - 0s 13ms/step - loss: 12.5669 - accuracy: 0.5700 - val_loss: 11.9070 - val_accuracy: 0.5100
# Epoch 11/100
# 1/1 [==============================] - 0s 13ms/step - loss: 10.5448 - accuracy: 0.5700 - val_loss: 10.0463 - val_accuracy: 0.5100
# Epoch 12/100
# 1/1 [==============================] - 0s 13ms/step - loss: 9.2278 - accuracy: 0.5700 - val_loss: 8.0490 - val_accuracy: 0.5100
# Epoch 13/100
# 1/1 [==============================] - 0s 13ms/step - loss: 7.6878 - accuracy: 0.5700 - val_loss: 5.9853 - val_accuracy: 0.4900
# Epoch 14/100
# 1/1 [==============================] - 0s 14ms/step - loss: 6.0167 - accuracy: 0.4300 - val_loss: 4.8241 - val_accuracy: 0.4900
# Epoch 15/100
# 1/1 [==============================] - 0s 13ms/step - loss: 5.1602 - accuracy: 0.4300 - val_loss: 5.2857 - val_accuracy: 0.4900
# Epoch 16/100
# 1/1 [==============================] - 0s 12ms/step - loss: 5.7467 - accuracy: 0.4300 - val_loss: 5.3486 - val_accuracy: 0.4900
# Epoch 17/100
# 1/1 [==============================] - 0s 13ms/step - loss: 5.7889 - accuracy: 0.4300 - val_loss: 5.9536 - val_accuracy: 0.4900
# Epoch 18/100
# 1/1 [==============================] - 0s 14ms/step - loss: 6.2966 - accuracy: 0.4300 - val_loss: 6.5078 - val_accuracy: 0.4900
# Epoch 19/100
# 1/1 [==============================] - 0s 13ms/step - loss: 6.7367 - accuracy: 0.4300 - val_loss: 6.6844 - val_accuracy: 0.4900
# Epoch 20/100
# 1/1 [==============================] - 0s 13ms/step - loss: 6.7972 - accuracy: 0.4300 - val_loss: 6.5151 - val_accuracy: 0.5100
# Epoch 21/100
# 1/1 [==============================] - 0s 12ms/step - loss: 6.5116 - accuracy: 0.5700 - val_loss: 6.0490 - val_accuracy: 0.5100
# Epoch 22/100
# 1/1 [==============================] - 0s 14ms/step - loss: 5.9301 - accuracy: 0.5700 - val_loss: 5.3480 - val_accuracy: 0.5100
# Epoch 23/100
# 1/1 [==============================] - 0s 14ms/step - loss: 5.1160 - accuracy: 0.5700 - val_loss: 4.6894 - val_accuracy: 0.5100
# Epoch 24/100
# 1/1 [==============================] - 0s 13ms/step - loss: 4.3439 - accuracy: 0.5700 - val_loss: 4.6485 - val_accuracy: 0.5100
# Epoch 25/100
# 1/1 [==============================] - 0s 12ms/step - loss: 4.2403 - accuracy: 0.5700 - val_loss: 4.4557 - val_accuracy: 0.5100
# Epoch 26/100
# 1/1 [==============================] - 0s 12ms/step - loss: 4.0680 - accuracy: 0.5700 - val_loss: 3.9473 - val_accuracy: 0.5100
# Epoch 27/100
# 1/1 [==============================] - 0s 13ms/step - loss: 3.6592 - accuracy: 0.5700 - val_loss: 3.8175 - val_accuracy: 0.5100
# Epoch 28/100
# 1/1 [==============================] - 0s 12ms/step - loss: 3.6855 - accuracy: 0.5700 - val_loss: 4.0341 - val_accuracy: 0.4900
# Epoch 29/100
# 1/1 [==============================] - 0s 13ms/step - loss: 4.0411 - accuracy: 0.4300 - val_loss: 4.0290 - val_accuracy: 0.4900
# Epoch 30/100
# 1/1 [==============================] - 0s 13ms/step - loss: 4.1434 - accuracy: 0.4300 - val_loss: 3.8130 - val_accuracy: 0.4900
# Epoch 31/100
# 1/1 [==============================] - 0s 13ms/step - loss: 4.0018 - accuracy: 0.4300 - val_loss: 3.5120 - val_accuracy: 0.4900
# Epoch 32/100
# 1/1 [==============================] - 0s 11ms/step - loss: 3.7349 - accuracy: 0.4300 - val_loss: 3.1758 - val_accuracy: 0.4900
# Epoch 33/100
# 1/1 [==============================] - 0s 13ms/step - loss: 3.3780 - accuracy: 0.4300 - val_loss: 2.7351 - val_accuracy: 0.4900
# Epoch 34/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.8422 - accuracy: 0.4300 - val_loss: 2.6969 - val_accuracy: 0.5100
# Epoch 35/100
# 1/1 [==============================] - 0s 11ms/step - loss: 2.6539 - accuracy: 0.5700 - val_loss: 3.1211 - val_accuracy: 0.5100
# Epoch 36/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.9493 - accuracy: 0.5700 - val_loss: 3.4369 - val_accuracy: 0.5100
# Epoch 37/100
# 1/1 [==============================] - 0s 13ms/step - loss: 3.1853 - accuracy: 0.5700 - val_loss: 3.5235 - val_accuracy: 0.5100
# Epoch 38/100
# 1/1 [==============================] - 0s 14ms/step - loss: 3.2495 - accuracy: 0.5700 - val_loss: 3.3935 - val_accuracy: 0.5100
# Epoch 39/100
# 1/1 [==============================] - 0s 12ms/step - loss: 3.1491 - accuracy: 0.5700 - val_loss: 3.1155 - val_accuracy: 0.5100
# Epoch 40/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.9404 - accuracy: 0.5700 - val_loss: 2.7568 - val_accuracy: 0.5100
# Epoch 41/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.6723 - accuracy: 0.5700 - val_loss: 2.4351 - val_accuracy: 0.4900
# Epoch 42/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.4399 - accuracy: 0.4300 - val_loss: 2.4023 - val_accuracy: 0.4900
# Epoch 43/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.4742 - accuracy: 0.4300 - val_loss: 2.5030 - val_accuracy: 0.4900
# Epoch 44/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.5844 - accuracy: 0.4300 - val_loss: 2.5783 - val_accuracy: 0.4900
# Epoch 45/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.6232 - accuracy: 0.4300 - val_loss: 2.5431 - val_accuracy: 0.5100
# Epoch 46/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.5279 - accuracy: 0.5700 - val_loss: 2.3925 - val_accuracy: 0.5100
# Epoch 47/100
# 1/1 [==============================] - 0s 11ms/step - loss: 2.3147 - accuracy: 0.5700 - val_loss: 2.4845 - val_accuracy: 0.5100
# Epoch 48/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.3827 - accuracy: 0.5700 - val_loss: 2.5646 - val_accuracy: 0.5100
# Epoch 49/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.4749 - accuracy: 0.5700 - val_loss: 2.4321 - val_accuracy: 0.5100
# Epoch 50/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.3631 - accuracy: 0.5700 - val_loss: 2.2412 - val_accuracy: 0.5100
# Epoch 51/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.1992 - accuracy: 0.5700 - val_loss: 2.2481 - val_accuracy: 0.5100
# Epoch 52/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.2425 - accuracy: 0.5700 - val_loss: 2.3049 - val_accuracy: 0.4900
# Epoch 53/100
# 1/1 [==============================] - 0s 11ms/step - loss: 2.3240 - accuracy: 0.4300 - val_loss: 2.2350 - val_accuracy: 0.4900
# Epoch 54/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.2549 - accuracy: 0.4300 - val_loss: 2.1486 - val_accuracy: 0.5100
# Epoch 55/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.1468 - accuracy: 0.5700 - val_loss: 2.1959 - val_accuracy: 0.5100
# Epoch 56/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.1636 - accuracy: 0.5700 - val_loss: 2.2681 - val_accuracy: 0.5100
# Epoch 57/100
# 1/1 [==============================] - 0s 14ms/step - loss: 2.2086 - accuracy: 0.5700 - val_loss: 2.2572 - val_accuracy: 0.5100
# Epoch 58/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.1839 - accuracy: 0.5700 - val_loss: 2.1856 - val_accuracy: 0.5100
# Epoch 59/100
# 1/1 [==============================] - 0s 11ms/step - loss: 2.1214 - accuracy: 0.5700 - val_loss: 2.1273 - val_accuracy: 0.5100
# Epoch 60/100
# 1/1 [==============================] - 0s 14ms/step - loss: 2.0938 - accuracy: 0.5700 - val_loss: 2.1212 - val_accuracy: 0.4900
# Epoch 61/100
# 1/1 [==============================] - 0s 11ms/step - loss: 2.1231 - accuracy: 0.4300 - val_loss: 2.1061 - val_accuracy: 0.4900
# Epoch 62/100
# 1/1 [==============================] - 0s 11ms/step - loss: 2.1248 - accuracy: 0.4300 - val_loss: 2.0704 - val_accuracy: 0.4900
# Epoch 63/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.0783 - accuracy: 0.4300 - val_loss: 2.0738 - val_accuracy: 0.5100
# Epoch 64/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.0517 - accuracy: 0.5700 - val_loss: 2.1203 - val_accuracy: 0.5100
# Epoch 65/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.0691 - accuracy: 0.5700 - val_loss: 2.1386 - val_accuracy: 0.5100
# Epoch 66/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.0745 - accuracy: 0.5700 - val_loss: 2.1005 - val_accuracy: 0.5100
# Epoch 67/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.0454 - accuracy: 0.5700 - val_loss: 2.0468 - val_accuracy: 0.5100
# Epoch 68/100
# 1/1 [==============================] - 0s 14ms/step - loss: 2.0174 - accuracy: 0.5700 - val_loss: 2.0275 - val_accuracy: 0.5100
# Epoch 69/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.0275 - accuracy: 0.5700 - val_loss: 2.0240 - val_accuracy: 0.4900
# Epoch 70/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.0300 - accuracy: 0.4300 - val_loss: 2.0145 - val_accuracy: 0.5100
# Epoch 71/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.0079 - accuracy: 0.5700 - val_loss: 2.0199 - val_accuracy: 0.5100
# Epoch 72/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.9903 - accuracy: 0.5700 - val_loss: 2.0411 - val_accuracy: 0.5100
# Epoch 73/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1.9943 - accuracy: 0.5700 - val_loss: 2.0437 - val_accuracy: 0.5100
# Epoch 74/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1.9949 - accuracy: 0.5700 - val_loss: 2.0173 - val_accuracy: 0.5100
# Epoch 75/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.9805 - accuracy: 0.5700 - val_loss: 1.9868 - val_accuracy: 0.5100
# Epoch 76/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1.9673 - accuracy: 0.5700 - val_loss: 1.9745 - val_accuracy: 0.5100
# Epoch 77/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1.9664 - accuracy: 0.5700 - val_loss: 1.9744 - val_accuracy: 0.5100
# Epoch 78/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1.9649 - accuracy: 0.5700 - val_loss: 1.9758 - val_accuracy: 0.5100
# Epoch 79/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1.9547 - accuracy: 0.5700 - val_loss: 1.9787 - val_accuracy: 0.5100
# Epoch 80/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.9450 - accuracy: 0.5700 - val_loss: 1.9797 - val_accuracy: 0.5100
# Epoch 81/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1.9411 - accuracy: 0.5700 - val_loss: 1.9710 - val_accuracy: 0.5100
# Epoch 82/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1.9378 - accuracy: 0.5700 - val_loss: 1.9464 - val_accuracy: 0.5100
# Epoch 83/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.9359 - accuracy: 0.5700 - val_loss: 1.9509 - val_accuracy: 0.5100
# Epoch 84/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1.9208 - accuracy: 0.5700 - val_loss: 1.9476 - val_accuracy: 0.5100
# Epoch 85/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1.9167 - accuracy: 0.5700 - val_loss: 1.9403 - val_accuracy: 0.5100
# Epoch 86/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1.9134 - accuracy: 0.5700 - val_loss: 1.9276 - val_accuracy: 0.5100
# Epoch 87/100
# 1/1 [==============================] - 0s 11ms/step - loss: 1.9062 - accuracy: 0.5700 - val_loss: 1.9172 - val_accuracy: 0.5100
# Epoch 88/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1.8985 - accuracy: 0.5700 - val_loss: 1.9145 - val_accuracy: 0.5100
# Epoch 89/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1.8935 - accuracy: 0.5700 - val_loss: 1.9159 - val_accuracy: 0.5100
# Epoch 90/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1.8890 - accuracy: 0.5700 - val_loss: 1.9147 - val_accuracy: 0.5100
# Epoch 91/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.8827 - accuracy: 0.5700 - val_loss: 1.9079 - val_accuracy: 0.5100
# Epoch 92/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.8757 - accuracy: 0.5700 - val_loss: 1.8971 - val_accuracy: 0.5100
# Epoch 93/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1.8699 - accuracy: 0.5700 - val_loss: 1.8859 - val_accuracy: 0.5100
# Epoch 94/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1.8650 - accuracy: 0.5700 - val_loss: 1.8771 - val_accuracy: 0.5100
# Epoch 95/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.8590 - accuracy: 0.5700 - val_loss: 1.8725 - val_accuracy: 0.5100
# Epoch 96/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1.8518 - accuracy: 0.5700 - val_loss: 1.8726 - val_accuracy: 0.5100
# Epoch 97/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1.8460 - accuracy: 0.5700 - val_loss: 1.8722 - val_accuracy: 0.5100
# Epoch 98/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1.8409 - accuracy: 0.5700 - val_loss: 1.8659 - val_accuracy: 0.5100
# Epoch 99/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1.8346 - accuracy: 0.5700 - val_loss: 1.8548 - val_accuracy: 0.5100
# Epoch 100/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1.8277 - accuracy: 0.5700 - val_loss: 1.8438 - val_accuracy: 0.5100

# %%
import pandas as pd
res=pd.DataFrame(history.history)

# Add row index as a new column
res.reset_index(inplace=True)

# Rename the new column to 'row_id'
res.rename(columns={'index': 'epoch'}, inplace=True)
res
# Out:
#     epoch       loss  accuracy   val_loss  val_accuracy
# 0       0  41.372337      0.57  41.160973          0.51
# 1       1  36.453896      0.57  36.250919          0.51
# 2       2  31.678970      0.57  31.518814          0.51
# 3       3  27.047258      0.57  28.464750          0.51
# 4       4  24.042246      0.57  26.741783          0.51
# ..    ...        ...       ...        ...           ...
# 95     95   1.851849      0.57   1.872633          0.51
# 96     96   1.845952      0.57   1.872194          0.51
# 97     97   1.840925      0.57   1.865944          0.51
# 98     98   1.834630      0.57   1.854755          0.51
# 99     99   1.827720      0.57   1.843765          0.51
#
# [100 rows x 5 columns]

# %%
history.history['accuracy']

import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="whitegrid")
line1 = sns.lineplot(x="epoch", y='loss', data=res, label='Training Loss')
line2 = sns.lineplot(x="epoch", y='val_loss', data=res, label='Test Loss')


# Add points to each observation
scatter1 = sns.scatterplot(x="epoch", y='loss', data=res, marker='o', color='skyblue')
scatter2 = sns.scatterplot(x="epoch", y='val_loss', data=res, marker='o', color='orange')

# Change the y-axis label
plt.ylabel("Loss Value")

# Create a legend for the lines
plt.legend()

# Show the plot
plt.show()

# %%
sns.set_theme(style="whitegrid")
line1 = sns.lineplot(x="epoch", y="accuracy", data=res, label='Training Accuracy')
line2 = sns.lineplot(x="epoch", y="val_accuracy", data=res, label='Test Accuracy')

# Add points to each observation
scatter1 = sns.scatterplot(x="epoch", y="accuracy", data=res, marker='o', color='skyblue')
scatter2 = sns.scatterplot(x="epoch", y="val_accuracy", data=res, marker='o', color='orange')

# Change the y-axis label
plt.ylabel("Accuracy Value")

# Create a legend for the lines
plt.legend()

# Show the plot
plt.show()

# %%
predictions = []
targets = []
step = 0
while step < test_loader.steps_per_epoch:
        step += 1
        inputs, target = test_loader.__next__()
        pred = model(inputs, training=False)
        predictions.append(pred)
        targets.append(target)
    
predictions = np.vstack(predictions)
    
targets = np.vstack(targets)
# Post-process the predictions if necessary (e.g., convert probabilities to class labels)
predicted_values = np.argmax(predictions, axis=1)
true_labels = np.argmax(targets,axis =1 )

# %%
from sklearn.metrics import confusion_matrix,roc_auc_score,accuracy_score
conf_mat = confusion_matrix(predicted_values, true_labels)
print(conf_mat)
# Out:
# [[ 0  0]
#  [49 51]]

# %%
auc_score = roc_auc_score(true_labels, predicted_values)
accuracy_score = accuracy_score(true_labels, predicted_values)

print("AUC Score:", auc_score)
print("Accuracy Score:", accuracy_score)
# Out:
# AUC Score: 0.5
# Accuracy Score: 0.51
