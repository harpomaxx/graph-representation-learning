# %%
# !pip install networkx
# Out:
# Requirement already satisfied: networkx in /usr/local/lib/python3.8/dist-packages (3.1)
# WARNING: You are using pip version 20.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      |████████████████████████████████| 293 kB 928 kB/s eta 0:00:01
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /usr/local/lib/python3.8/dist-packages (from seaborn) (3.6.2)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.8/dist-packages (from seaborn) (1.5.3)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /usr/local/lib/python3.8/dist-packages (from seaborn) (1.23.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.3.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.14.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.12.2
# WARNING: You are using pip version 20.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import networkx as nx

import os
import numpy as np
import matplotlib.pyplot as plt
import gc

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

from spektral.data import Dataset, Graph
from spektral.layers import GraphSageConv
from spektral.utils import normalized_adjacency
from spektral.models.gcn import GCN 
from spektral.datasets.utils import DATASET_FOLDER

from scipy import sparse
from scipy.special import softmax

from sklearn.model_selection import train_test_split

# %%
def plot_graph(G, communities=None):
    pos = nx.spring_layout(G, seed=42)
    
    if communities is not None:
        # Assign colors to nodes based on their communities
        colors = ['orange' if community == 0 else 'skyblue' for community in communities]
    else:
        colors = 'red'

    nx.draw(G, pos, node_color=colors, with_labels=True)
    plt.show()

# %% [markdown]
# # Caso 1: no dirigido, diferentes tamaños, balanceado, clases separadas
#
# No dirigido, i.e. matriz de adyacencia simétrica
#
# Tamaños (número de nodos): 25, 50, 100, 200, 400, 800, 1600, 3200, 6400, 12800
#
# Clases "separadas"

# %%
class synthetic_NoDir_diffSize_balanced_clasesSep(Dataset):
    
    def __init__(self, **kwargs):
        super().__init__(**kwargs)

    @property
    def path(self):
        return os.path.join(DATASET_FOLDER, "syntheticGraphs", self.__class__.__name__)
    
    def download(self):
        os.makedirs(self.path)
        
        def generate_synthetic_graph_csbm(n_nodes, n_communities, n_features, edge_prob_matrix, node_feature_means,\
                                  semilla, indice, feature_cov_matrix=None):
            # Assign nodes to communities
            np.random.seed(semilla*(indice+1))
            communities = np.random.randint(0, n_communities, n_nodes)

            # Generate node features
            if feature_cov_matrix is None:
                feature_cov_matrix = np.eye(n_features)
            features = np.zeros((n_nodes, n_features))
            for k in range(n_communities):
                nodes_in_community = np.where(communities == k)[0]
                features[nodes_in_community] = np.random.multivariate_normal(node_feature_means[k], feature_cov_matrix,\
                                                                             len(nodes_in_community))

            # Compute community membership probabilities based on node features
            community_membership_probs = softmax(features @ node_feature_means.T, axis=1)

            # Generate edges based on community membership probabilities
            adjacency_matrix = np.zeros((n_nodes, n_nodes))
            for i in range(n_nodes):
                for j in range(i, n_nodes):
                    if i == j:
                        continue
                    community_i = communities[i]
                    community_j = communities[j]
                    edge_prob = edge_prob_matrix[community_i, community_j] * community_membership_probs[i, community_j] * community_membership_probs[j, community_i]
                    adjacency_matrix[i, j] = adjacency_matrix[j, i] = np.random.binomial(1, edge_prob)

            labels = tf.keras.utils.to_categorical(communities)
            adjacency_matrix = sparse.csr_matrix(adjacency_matrix)
            return Graph(x=features, a=adjacency_matrix, y=labels)

        
        n_graphs = 10
        n_nodes = [25, 50, 100, 200, 400, 800, 1600, 3200, 6400, 12800]
        n_features = 2
        n_classes = 2
        # Probability matrix for edges between communities
        edge_prob_matrix = np.array([
                                        [0.8, 0.2],
                                        [0.3, 0.7]
                                    ])
        # Node feature means for each community
        node_feature_means = np.array([
                                        [2, 1], #, 0, 0, 0],
                                        [1, 2] #, 0, 0, 0]
                                    ])
        
        semillas = [123, 234, 345, 456, 567, 678, 789, 321, 654, 987]
        
        # Bien separadas las clases:
        graphs1 = [generate_synthetic_graph_csbm(n_nodes[i], n_classes, n_features, edge_prob_matrix, node_feature_means, semillas[i], 0, feature_cov_matrix=None) for i in range(n_graphs)]
        for j in range(10):
            filename = os.path.join(self.path, f'graph_NoDir_{n_nodes[j]}nodes_balanced_clasesSep_0{j}.npz')
            np.savez(filename, x=graphs1[j].x, a=graphs1[j].a, y=graphs1[j].y)

        # Free memory
        del graphs1
        gc.collect()


    def read(self):
        # We must return a list of Graph objects
        output = []
        
        n_nodes = [25, 50, 100, 200, 400, 800, 1600, 3200, 6400, 12800]
        
        for j in range(10):
            data1 = np.load(os.path.join(self.path, f'graph_NoDir_{n_nodes[j]}nodes_balanced_clasesSep_0{j}.npz'), allow_pickle=True)
            output.append(
                Graph(x=data1['x'], a=data1['a'][()], y=data1['y']) # también puede ser a=data['a'].item()
            )

        return output

# %%
dataset1 = synthetic_NoDir_diffSize_balanced_clasesSep()

# %%
for G in dataset1:
    nxG = nx.from_numpy_array(G.a)
    labels = np.argmax(G.y,axis=1)
    plot_graph(nxG,labels)
# Out:
# KeyboardInterruptTraceback (most recent call last)
# Cell In [5], line 2
#       1 for G in dataset1:
# ----> 2     nxG = nx.from_numpy_array(G.a)
#       3     labels = np.argmax(G.y,axis=1)
#       4     plot_graph(nxG,labels)
#
# File /usr/local/lib/python3.8/dist-packages/networkx/convert_matrix.py:1161, in from_numpy_array(A, parallel_edges, create_using)
#    1159 if G.is_multigraph() and not G.is_directed():
#    1160     triples = ((u, v, d) for u, v, d in triples if u <= v)
# -> 1161 G.add_edges_from(triples)
#    1162 return G
#
# File /usr/local/lib/python3.8/dist-packages/networkx/classes/graph.py:1016, in Graph.add_edges_from(self, ebunch_to_add, **attr)
#     961 def add_edges_from(self, ebunch_to_add, **attr):
#     962     """Add all the edges in ebunch_to_add.
#     963
#     964     Parameters
#    (...)
#    1014     >>> G.add_edges_from(list((5, n) for n in G.nodes))
#    1015     """
# -> 1016     for e in ebunch_to_add:
#    1017         ne = len(e)
#    1018         if ne == 3:
#
# File /usr/local/lib/python3.8/dist-packages/networkx/convert_matrix.py:1150, in <genexpr>(.0)
#    1146     triples = chain(
#    1147         ((u, v, {"weight": 1}) for d in range(A[u, v])) for (u, v) in edges
#    1148     )
#    1149 else:  # basic data type
# -> 1150     triples = ((u, v, {"weight": python_type(A[u, v])}) for u, v in edges)
#    1151 # If we are creating an undirected multigraph, only add the edges from the
#    1152 # upper triangle of the matrix. Otherwise, add all the edges. This relies
#    1153 # on the fact that the vertices created in the
#    (...)
#    1157 # Without this check, we run into a problem where each edge is added twice
#    1158 # when `G.add_edges_from()` is invoked below.
#    1159 if G.is_multigraph() and not G.is_directed():
#
# File /usr/local/lib/python3.8/dist-packages/scipy/sparse/_index.py:52, in IndexMixin.__getitem__(self, key)
#      50 if isinstance(row, INT_TYPES):
#      51     if isinstance(col, INT_TYPES):
# ---> 52         return self._get_intXint(row, col)
#      53     elif isinstance(col, slice):
#      54         self._raise_on_1d_array_slice()
#
# File /usr/local/lib/python3.8/dist-packages/scipy/sparse/_compressed.py:657, in _cs_matrix._get_intXint(self, row, col)
#     655 M, N = self._swap(self.shape)
#     656 major, minor = self._swap((row, col))
# --> 657 indptr, indices, data = get_csr_submatrix(
#     658     M, N, self.indptr, self.indices, self.data,
#     659     major, major + 1, minor, minor + 1)
#     660 return data.sum(dtype=self.dtype)
#
# KeyboardInterrupt:

# %% [markdown]
# # Caso 2: no dirigido, diferentes tamaños, balanceado, clases más juntas
#
# No dirigido, i.e. matriz de adyacencia simétrica
#
# Tamaños (número de nodos): 25, 50, 100, 200, 400, 800, 1600, 3200, 6400, 12800
#
# Clases "más juntas"

# %%
class synthetic_NoDir_diffSize_balanced_clasesJunt(Dataset):
    
    def __init__(self, **kwargs):
        super().__init__(**kwargs)

    @property
    def path(self):
        return os.path.join(DATASET_FOLDER, "syntheticGraphs", self.__class__.__name__)
    
    def download(self):
        os.makedirs(self.path)
        
        def generate_synthetic_graph_csbm(n_nodes, n_communities, n_features, edge_prob_matrix, node_feature_means,\
                                  semilla, indice, feature_cov_matrix=None):
            # Assign nodes to communities
            np.random.seed(semilla*(indice+1))
            communities = np.random.randint(0, n_communities, n_nodes)

            # Generate node features
            if feature_cov_matrix is None:
                feature_cov_matrix = np.eye(n_features)
            features = np.zeros((n_nodes, n_features))
            for k in range(n_communities):
                nodes_in_community = np.where(communities == k)[0]
                features[nodes_in_community] = np.random.multivariate_normal(node_feature_means[k], feature_cov_matrix,\
                                                                             len(nodes_in_community))

            # Compute community membership probabilities based on node features
            community_membership_probs = softmax(features @ node_feature_means.T, axis=1)

            # Generate edges based on community membership probabilities
            adjacency_matrix = np.zeros((n_nodes, n_nodes))
            for i in range(n_nodes):
                for j in range(i, n_nodes):
                    if i == j:
                        continue
                    community_i = communities[i]
                    community_j = communities[j]
                    edge_prob = edge_prob_matrix[community_i, community_j] * community_membership_probs[i, community_j] * community_membership_probs[j, community_i]
                    adjacency_matrix[i, j] = adjacency_matrix[j, i] = np.random.binomial(1, edge_prob)

            labels = tf.keras.utils.to_categorical(communities)
            adjacency_matrix = sparse.csr_matrix(adjacency_matrix)
            return Graph(x=features, a=adjacency_matrix, y=labels)

        
        n_graphs = 10
        n_nodes = [25, 50, 100, 200, 400, 800, 1600, 3200, 6400, 12800]
        n_features = 2
        n_classes = 2
        # Probability matrix for edges between communities
        edge_prob_matrix = np.array([
                                    [0.5, 0.5],
                                    [0.5, 0.5]
                            ])
        # Node feature means for each community
        node_feature_means = np.array([
                                        [2, 1], #, 0, 0, 0],
                                        [1, 2] #, 0, 0, 0]
                                    ])
        
        semillas = [123, 234, 345, 456, 567, 678, 789, 321, 654, 987]
        
        # Clases un poco más juntas:
        graphs2 = [generate_synthetic_graph_csbm(n_nodes[i], n_classes, n_features, edge_prob_matrix, node_feature_means, semillas[i], 1, feature_cov_matrix=None) for i in range(n_graphs)]
        for j in range(10):
            filename = os.path.join(self.path, f'graph_NoDir_{n_nodes[j]}nodes_balanced_clasesJunt_1{j}.npz')
            np.savez(filename, x=graphs2[j].x, a=graphs2[j].a, y=graphs2[j].y)

        # Free memory
        del graphs2
        gc.collect()


    def read(self):
        # We must return a list of Graph objects
        output = []
        
        n_nodes = [25, 50, 100, 200, 400, 800, 1600, 3200, 6400, 12800]
        
        for j in range(10):
            data2 = np.load(os.path.join(self.path, f'graph_NoDir_{n_nodes[j]}nodes_balanced_clasesJunt_1{j}.npz'), allow_pickle=True)
            output.append(
                Graph(x=data2['x'], a=data2['a'][()], y=data2['y']) # también puede ser a=data['a'].item()
            )

        return output

# %%
dataset2 = synthetic_NoDir_diffSize_balanced_clasesJunt()

# %%
for G in dataset2:
    nxG = nx.from_numpy_array(G.a)
    labels = np.argmax(G.y,axis=1)
    plot_graph(nxG,labels)
# Out:
# KeyboardInterruptTraceback (most recent call last)
# Cell In [13], line 4
#       2 nxG = nx.from_numpy_array(G.a)
#       3 labels = np.argmax(G.y,axis=1)
# ----> 4 plot_graph(nxG,labels)
#
# Cell In [2], line 2, in plot_graph(G, communities)
#       1 def plot_graph(G, communities=None):
# ----> 2     pos = nx.spring_layout(G, seed=42)
#       4     if communities is not None:
#       5         # Assign colors to nodes based on their communities
#       6         colors = ['orange' if community == 0 else 'skyblue' for community in communities]
#
# File <class 'networkx.utils.decorators.argmap'> compilation 8:4, in argmap_spring_layout_5(G, k, pos, fixed, iterations, threshold, weight, scale, center, dim, seed)
#       2 import collections
#       3 import gzip
# ----> 4 import inspect
#       5 import itertools
#       6 import re
#
# File /usr/local/lib/python3.8/dist-packages/networkx/drawing/layout.py:482, in spring_layout(G, k, pos, fixed, iterations, threshold, weight, scale, center, dim, seed)
#     480         nnodes, _ = A.shape
#     481         k = dom_size / np.sqrt(nnodes)
# --> 482     pos = _sparse_fruchterman_reingold(
#     483         A, k, pos_arr, fixed, iterations, threshold, dim, seed
#     484     )
#     485 except ValueError:
#     486     A = nx.to_numpy_array(G, weight=weight)
#
# File <class 'networkx.utils.decorators.argmap'> compilation 16:4, in argmap__sparse_fruchterman_reingold_13(A, k, pos, fixed, iterations, threshold, dim, seed)
#       2 import collections
#       3 import gzip
# ----> 4 import inspect
#       5 import itertools
#       6 import re
#
# File /usr/local/lib/python3.8/dist-packages/networkx/drawing/layout.py:625, in _sparse_fruchterman_reingold(A, k, pos, fixed, iterations, threshold, dim, seed)
#     622     Ai = A.getrowview(i).toarray()  # TODO: revisit w/ sparse 1D container
#     623     # displacement "force"
#     624     displacement[:, i] += (
# --> 625         delta * (k * k / distance**2 - Ai * distance / k)
#     626     ).sum(axis=1)
#     627 # update positions
#     628 length = np.sqrt((displacement**2).sum(axis=0))
#
# KeyboardInterrupt:

# %% [markdown]
# # Caso 3: no dirigido, diferentes tamaños, balanceado, clases mezcladas
#
# No dirigido, i.e. matriz de adyacencia simétrica
#
# Tamaños: 25, 50, 100, 200, 400, 800, 1600, 3200, 6400, 12800
#
# Clases "mezcladas" (a juzgar por la representación gráfica)

# %%
class synthetic_NoDir_diffSize_balanced_clasesMezcl(Dataset):
    
    def __init__(self, **kwargs):
        super().__init__(**kwargs)

    @property
    def path(self):
        return os.path.join(DATASET_FOLDER, "syntheticGraphs", self.__class__.__name__)
    
    def download(self):
        os.makedirs(self.path)
        
        def generate_synthetic_graph_csbm(n_nodes, n_communities, n_features, edge_prob_matrix, node_feature_means,\
                                  semilla, indice, feature_cov_matrix=None):
            # Assign nodes to communities
            np.random.seed(semilla*(indice+1))
            communities = np.random.randint(0, n_communities, n_nodes)

            # Generate node features
            if feature_cov_matrix is None:
                feature_cov_matrix = np.eye(n_features)
            features = np.zeros((n_nodes, n_features))
            for k in range(n_communities):
                nodes_in_community = np.where(communities == k)[0]
                features[nodes_in_community] = np.random.multivariate_normal(node_feature_means[k], feature_cov_matrix,\
                                                                             len(nodes_in_community))

            # Compute community membership probabilities based on node features
            community_membership_probs = softmax(features @ node_feature_means.T, axis=1)

            # Generate edges based on community membership probabilities
            adjacency_matrix = np.zeros((n_nodes, n_nodes))
            for i in range(n_nodes):
                for j in range(i, n_nodes):
                    if i == j:
                        continue
                    community_i = communities[i]
                    community_j = communities[j]
                    edge_prob = edge_prob_matrix[community_i, community_j] * community_membership_probs[i, community_j] * community_membership_probs[j, community_i]
                    adjacency_matrix[i, j] = adjacency_matrix[j, i] = np.random.binomial(1, edge_prob)

            labels = tf.keras.utils.to_categorical(communities)
            adjacency_matrix = sparse.csr_matrix(adjacency_matrix)
            return Graph(x=features, a=adjacency_matrix, y=labels)

        
        n_graphs = 10
        n_nodes = [25, 50, 100, 200, 400, 800, 1600, 3200, 6400, 12800]
        n_features = 2
        n_classes = 2
        # Probability matrix for edges between communities
        edge_prob_matrix = np.array([
                                    [0.5, 0.5],
                                    [0.5, 0.5]
                            ])
        # Node feature means for each community
        node_feature_means = np.array([
                                        [1, 1], #, 0, 0, 0],
                                        [1, 1] #, 0, 0, 0]
                                    ])
        
        semillas = [123, 234, 345, 456, 567, 678, 789, 321, 654, 987]
        
        # Clases completamente mezcladas:
        graphs3 = [generate_synthetic_graph_csbm(n_nodes[i], n_classes, n_features, edge_prob_matrix, node_feature_means, semillas[i], 2, feature_cov_matrix=None) for i in range(n_graphs)]
        for j in range(10):
            filename = os.path.join(self.path, f'graph_NoDir_{n_nodes[j]}nodes_balanced_clasesMezcl_2{j}.npz')
            np.savez(filename, x=graphs3[j].x, a=graphs3[j].a, y=graphs3[j].y)
            
        # Free memory
        del graphs3
        gc.collect()


    def read(self):
        # We must return a list of Graph objects
        output = []

        n_nodes = [25, 50, 100, 200, 400, 800, 1600, 3200, 6400, 12800]
        
        for j in range(10):
            data3 = np.load(os.path.join(self.path, f'graph_NoDir_{n_nodes[j]}nodes_balanced_clasesMezcl_2{j}.npz'), allow_pickle=True)
            output.append(
                Graph(x=data3['x'], a=data3['a'][()], y=data3['y']) # también puede ser a=data['a'].item()
            )

        return output

# %%
dataset3 = synthetic_NoDir_diffSize_balanced_clasesMezcl()

# %%
for G in dataset3:
    nxG = nx.from_numpy_array(G.a)
    labels = np.argmax(G.y,axis=1)
    plot_graph(nxG,labels)
# Out:
# KeyboardInterruptTraceback (most recent call last)
# Cell In [19], line 4
#       2 nxG = nx.from_numpy_array(G.a)
#       3 labels = np.argmax(G.y,axis=1)
# ----> 4 plot_graph(nxG,labels)
#
# Cell In [2], line 10, in plot_graph(G, communities)
#       7 else:
#       8     colors = 'red'
# ---> 10 nx.draw(G, pos, node_color=colors, with_labels=True)
#      11 plt.show()
#
# File /usr/local/lib/python3.8/dist-packages/networkx/drawing/nx_pylab.py:121, in draw(G, pos, ax, **kwds)
#     118 if "with_labels" not in kwds:
#     119     kwds["with_labels"] = "labels" in kwds
# --> 121 draw_networkx(G, pos=pos, ax=ax, **kwds)
#     122 ax.set_axis_off()
#     123 plt.draw_if_interactive()
#
# File /usr/local/lib/python3.8/dist-packages/networkx/drawing/nx_pylab.py:304, in draw_networkx(G, pos, arrows, with_labels, **kwds)
#     301     pos = nx.drawing.spring_layout(G)  # default to spring layout
#     303 draw_networkx_nodes(G, pos, **node_kwds)
# --> 304 draw_networkx_edges(G, pos, arrows=arrows, **edge_kwds)
#     305 if with_labels:
#     306     draw_networkx_labels(G, pos, **label_kwds)
#
# File /usr/local/lib/python3.8/dist-packages/networkx/drawing/nx_pylab.py:896, in draw_networkx_edges(G, pos, edgelist, width, edge_color, style, alpha, arrowstyle, arrowsize, edge_cmap, edge_vmin, edge_vmax, ax, arrows, label, node_size, nodelist, node_shape, connectionstyle, min_source_margin, min_target_margin)
#     894 # Draw the edges
#     895 if use_linecollection:
# --> 896     edge_viz_obj = _draw_networkx_edges_line_collection()
#     897     # Make sure selfloop edges are also drawn
#     898     selfloops_to_draw = [loop for loop in nx.selfloop_edges(G) if loop in edgelist]
#
# File /usr/local/lib/python3.8/dist-packages/networkx/drawing/nx_pylab.py:738, in draw_networkx_edges.<locals>._draw_networkx_edges_line_collection()
#     737 def _draw_networkx_edges_line_collection():
# --> 738     edge_collection = mpl.collections.LineCollection(
#     739         edge_pos,
#     740         colors=edge_color,
#     741         linewidths=width,
#     742         antialiaseds=(1,),
#     743         linestyle=style,
#     744         alpha=alpha,
#     745     )
#     746     edge_collection.set_cmap(edge_cmap)
#     747     edge_collection.set_clim(edge_vmin, edge_vmax)
#
# File /usr/local/lib/python3.8/dist-packages/matplotlib/collections.py:1414, in LineCollection.__init__(self, segments, zorder, **kwargs)
#    1410 kwargs.setdefault('facecolors', 'none')
#    1411 super().__init__(
#    1412     zorder=zorder,
#    1413     **kwargs)
# -> 1414 self.set_segments(segments)
#
# File /usr/local/lib/python3.8/dist-packages/matplotlib/collections.py:1420, in LineCollection.set_segments(self, segments)
#    1417 if segments is None:
#    1418     return
# -> 1420 self._paths = [mpath.Path(seg) if isinstance(seg, np.ma.MaskedArray)
#    1421                else mpath.Path(np.asarray(seg, float))
#    1422                for seg in segments]
#    1423 self.stale = True
#
# File /usr/local/lib/python3.8/dist-packages/matplotlib/collections.py:1420, in <listcomp>(.0)
#    1417 if segments is None:
#    1418     return
# -> 1420 self._paths = [mpath.Path(seg) if isinstance(seg, np.ma.MaskedArray)
#    1421                else mpath.Path(np.asarray(seg, float))
#    1422                for seg in segments]
#    1423 self.stale = True
#
# KeyboardInterrupt:

# %% [markdown]
# # Caso 4: no dirigido, mismo tamaño, balanceado, clases separadas, features aplanadas
#
# Grafos iguales a los del caso 1, salvo que las features están aplanadas a 1

# %%
class synthetic_NoDir_diffSize_balanced_clasesSep_flattened(Dataset):
    
    def __init__(self, **kwargs):
        super().__init__(**kwargs)

    @property
    def path(self):
        return os.path.join(DATASET_FOLDER, "syntheticGraphs", self.__class__.__name__)
    
    def download(self):
        os.makedirs(self.path)
        
        def generate_synthetic_graph_csbm(n_nodes, n_communities, n_features, edge_prob_matrix, node_feature_means,\
                                  semilla, indice, feature_cov_matrix=None):
            # Assign nodes to communities
            np.random.seed(semilla*(indice+1))
            communities = np.random.randint(0, n_communities, n_nodes)

            # Generate node features
            if feature_cov_matrix is None:
                feature_cov_matrix = np.eye(n_features)
            features = np.zeros((n_nodes, n_features))
            for k in range(n_communities):
                nodes_in_community = np.where(communities == k)[0]
                features[nodes_in_community] = np.random.multivariate_normal(node_feature_means[k], feature_cov_matrix,\
                                                                             len(nodes_in_community))

            # Compute community membership probabilities based on node features
            community_membership_probs = softmax(features @ node_feature_means.T, axis=1)

            # Generate edges based on community membership probabilities
            adjacency_matrix = np.zeros((n_nodes, n_nodes))
            for i in range(n_nodes):
                for j in range(i, n_nodes):
                    if i == j:
                        continue
                    community_i = communities[i]
                    community_j = communities[j]
                    edge_prob = edge_prob_matrix[community_i, community_j] * community_membership_probs[i, community_j] * community_membership_probs[j, community_i]
                    adjacency_matrix[i, j] = adjacency_matrix[j, i] = np.random.binomial(1, edge_prob)

            labels = tf.keras.utils.to_categorical(communities)
            adjacency_matrix = sparse.csr_matrix(adjacency_matrix)
            return Graph(x=np.ones((n_nodes, n_features)), a=adjacency_matrix, y=labels)

        
        n_graphs = 10
        n_nodes = [25, 50, 100, 200, 400, 800, 1600, 3200, 6400, 12800]
        n_features = 2
        n_classes = 2
        # Probability matrix for edges between communities
        edge_prob_matrix = np.array([
                                        [0.8, 0.2],
                                        [0.3, 0.7]
                                    ])
        # Node feature means for each community
        node_feature_means = np.array([
                                        [2, 1], #, 0, 0, 0],
                                        [1, 2] #, 0, 0, 0]
                                    ])
        
        semillas = [123, 234, 345, 456, 567, 678, 789, 321, 654, 987]
        
        # Bien separadas las clases:
        graphs1 = [generate_synthetic_graph_csbm(n_nodes[i], n_classes, n_features, edge_prob_matrix, node_feature_means, semillas[i], 0, feature_cov_matrix=None) for i in range(n_graphs)]
        for j in range(10):
            filename = os.path.join(self.path, f'graph_NoDir_{n_nodes[j]}nodes_balanced_clasesSep_0{j}_flattened.npz')
            np.savez(filename, x=graphs1[j].x, a=graphs1[j].a, y=graphs1[j].y)

        # Free memory
        del graphs1
        gc.collect()


    def read(self):
        # We must return a list of Graph objects
        output = []

        n_nodes = [25, 50, 100, 200, 400, 800, 1600, 3200, 6400, 12800]
        
        for j in range(10):
            data1 = np.load(os.path.join(self.path, f'graph_NoDir_{n_nodes[j]}nodes_balanced_clasesSep_0{j}_flattened.npz'), allow_pickle=True)
            output.append(
                Graph(x=data1['x'], a=data1['a'][()], y=data1['y']) # también puede ser a=data['a'].item()
            )

        return output

# %%
dataset4 = synthetic_NoDir_diffSize_balanced_clasesSep_flattened()

# %% [markdown]
# # Caso 5: no dirigido, diferentes tamaños, balanceado, clases más juntas, features aplanadas
#
# Grafos iguales a los del caso 2, salvo que las features están aplanadas a 1

# %%
class synthetic_NoDir_diffSize_balanced_clasesJunt_flattened(Dataset):
    
    def __init__(self, **kwargs):
        super().__init__(**kwargs)

    @property
    def path(self):
        return os.path.join(DATASET_FOLDER, "syntheticGraphs", self.__class__.__name__)
    
    def download(self):
        os.makedirs(self.path)
        
        def generate_synthetic_graph_csbm(n_nodes, n_communities, n_features, edge_prob_matrix, node_feature_means,\
                                  semilla, indice, feature_cov_matrix=None):
            # Assign nodes to communities
            np.random.seed(semilla*(indice+1))
            communities = np.random.randint(0, n_communities, n_nodes)

            # Generate node features
            if feature_cov_matrix is None:
                feature_cov_matrix = np.eye(n_features)
            features = np.zeros((n_nodes, n_features))
            for k in range(n_communities):
                nodes_in_community = np.where(communities == k)[0]
                features[nodes_in_community] = np.random.multivariate_normal(node_feature_means[k], feature_cov_matrix,\
                                                                             len(nodes_in_community))

            # Compute community membership probabilities based on node features
            community_membership_probs = softmax(features @ node_feature_means.T, axis=1)

            # Generate edges based on community membership probabilities
            adjacency_matrix = np.zeros((n_nodes, n_nodes))
            for i in range(n_nodes):
                for j in range(i, n_nodes):
                    if i == j:
                        continue
                    community_i = communities[i]
                    community_j = communities[j]
                    edge_prob = edge_prob_matrix[community_i, community_j] * community_membership_probs[i, community_j] * community_membership_probs[j, community_i]
                    adjacency_matrix[i, j] = adjacency_matrix[j, i] = np.random.binomial(1, edge_prob)

            labels = tf.keras.utils.to_categorical(communities)
            adjacency_matrix = sparse.csr_matrix(adjacency_matrix)
            return Graph(x=np.ones((n_nodes, n_features)), a=adjacency_matrix, y=labels)

        
        n_graphs = 10
        n_nodes = [25, 50, 100, 200, 400, 800, 1600, 3200, 6400, 12800]
        n_features = 2
        n_classes = 2
        # Probability matrix for edges between communities
        edge_prob_matrix = np.array([
                                    [0.5, 0.5],
                                    [0.5, 0.5]
                            ])
        # Node feature means for each community
        node_feature_means = np.array([
                                        [2, 1], #, 0, 0, 0],
                                        [1, 2] #, 0, 0, 0]
                                    ])
        
        semillas = [123, 234, 345, 456, 567, 678, 789, 321, 654, 987]
        
        # Clases un poco más juntas:
        graphs2 = [generate_synthetic_graph_csbm(n_nodes[i], n_classes, n_features, edge_prob_matrix, node_feature_means, semillas[i], 1, feature_cov_matrix=None) for i in range(n_graphs)]
        for j in range(10):
            filename = os.path.join(self.path, f'graph_NoDir_{n_nodes[j]}nodes_balanced_clasesJunt_1{j}_flattened.npz')
            np.savez(filename, x=graphs2[j].x, a=graphs2[j].a, y=graphs2[j].y)

        # Free memory
        del graphs2
        gc.collect()


    def read(self):
        # We must return a list of Graph objects
        output = []

        n_nodes = [25, 50, 100, 200, 400, 800, 1600, 3200, 6400, 12800]
        
        for j in range(10):
            data2 = np.load(os.path.join(self.path, f'graph_NoDir_{n_nodes[j]}nodes_balanced_clasesJunt_1{j}_flattened.npz'), allow_pickle=True)
            output.append(
                Graph(x=data2['x'], a=data2['a'][()], y=data2['y']) # también puede ser a=data['a'].item()
            )

        return output

# %%
dataset5 = synthetic_NoDir_diffSize_balanced_clasesJunt_flattened()

# %% [markdown]
# # Caso 6: no dirigido, diferentes tamaños, balanceado, clases mezcladas, features aplanadas
#
# Grafos iguales a los del caso 3, salvo que las features están aplanadas a 1

# %%
class synthetic_NoDir_diffSize_balanced_clasesMezcl_flattened(Dataset):
    
    def __init__(self, **kwargs):
        super().__init__(**kwargs)

    @property
    def path(self):
        return os.path.join(DATASET_FOLDER, "syntheticGraphs", self.__class__.__name__)
    
    def download(self):
        os.makedirs(self.path)
        
        def generate_synthetic_graph_csbm(n_nodes, n_communities, n_features, edge_prob_matrix, node_feature_means,\
                                  semilla, indice, feature_cov_matrix=None):
            # Assign nodes to communities
            np.random.seed(semilla*(indice+1))
            communities = np.random.randint(0, n_communities, n_nodes)

            # Generate node features
            if feature_cov_matrix is None:
                feature_cov_matrix = np.eye(n_features)
            features = np.zeros((n_nodes, n_features))
            for k in range(n_communities):
                nodes_in_community = np.where(communities == k)[0]
                features[nodes_in_community] = np.random.multivariate_normal(node_feature_means[k], feature_cov_matrix,\
                                                                             len(nodes_in_community))

            # Compute community membership probabilities based on node features
            community_membership_probs = softmax(features @ node_feature_means.T, axis=1)

            # Generate edges based on community membership probabilities
            adjacency_matrix = np.zeros((n_nodes, n_nodes))
            for i in range(n_nodes):
                for j in range(i, n_nodes):
                    if i == j:
                        continue
                    community_i = communities[i]
                    community_j = communities[j]
                    edge_prob = edge_prob_matrix[community_i, community_j] * community_membership_probs[i, community_j] * community_membership_probs[j, community_i]
                    adjacency_matrix[i, j] = adjacency_matrix[j, i] = np.random.binomial(1, edge_prob)

            labels = tf.keras.utils.to_categorical(communities)
            adjacency_matrix = sparse.csr_matrix(adjacency_matrix)
            return Graph(x=np.ones((n_nodes, n_features)), a=adjacency_matrix, y=labels)

        
        n_graphs = 10
        n_nodes = [25, 50, 100, 200, 400, 800, 1600, 3200, 6400, 12800]
        n_features = 2
        n_classes = 2
        # Probability matrix for edges between communities
        edge_prob_matrix = np.array([
                                    [0.5, 0.5],
                                    [0.5, 0.5]
                            ])
        # Node feature means for each community
        node_feature_means = np.array([
                                        [1, 1], #, 0, 0, 0],
                                        [1, 1] #, 0, 0, 0]
                                    ])
        
        semillas = [123, 234, 345, 456, 567, 678, 789, 321, 654, 987]
        
        # Clases completamente mezcladas:
        graphs3 = [generate_synthetic_graph_csbm(n_nodes[i], n_classes, n_features, edge_prob_matrix, node_feature_means, semillas[i], 2, feature_cov_matrix=None) for i in range(n_graphs)]
        for j in range(10):
            filename = os.path.join(self.path, f'graph_NoDir_{n_nodes[j]}nodes_balanced_clasesMezcl_2{j}_flattened.npz')
            np.savez(filename, x=graphs3[j].x, a=graphs3[j].a, y=graphs3[j].y)
            
        # Free memory
        del graphs3
        gc.collect()


    def read(self):
        # We must return a list of Graph objects
        output = []

        n_nodes = [25, 50, 100, 200, 400, 800, 1600, 3200, 6400, 12800]
        
        for j in range(10):
            data3 = np.load(os.path.join(self.path, f'graph_NoDir_{n_nodes[j]}nodes_balanced_clasesMezcl_2{j}_flattened.npz'), allow_pickle=True)
            output.append(
                Graph(x=data3['x'], a=data3['a'][()], y=data3['y']) # también puede ser a=data['a'].item()
            )

        return output

# %%
dataset6 = synthetic_NoDir_diffSize_balanced_clasesMezcl_flattened()
