# %%
import pandas as pd

# %%
df=pd.read_csv('../../rawdata/ctu-13/capture20110810.binetflow.labels.gz')

# %%
df2=df[["SrcAddr","DstAddr","TotBytes","SrcBytes"]]
df2["DstBytes"]=df2["TotBytes"]-df2["SrcBytes"]
df2.drop('TotBytes',inplace=True, axis=1)
df2
# Out:
# <ipython-input-3-fc89c909f5f6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["DstBytes"]=df2["TotBytes"]-df2["SrcBytes"]
# C:\Users\eduma\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                SrcAddr        DstAddr  SrcBytes  DstBytes
# 0        212.50.71.179  147.32.84.229       413       462
# 1        84.13.246.132  147.32.84.229        75        60
# 2        217.163.21.35  147.32.86.194        60        60
# ...

# %% [markdown]
# ## Intento 1 (2,15M de años)

# %% [markdown]
# * La idea es crear otro dataframe vacío al que le voy agregando los pares de ips que NO se hayan agregado ya, y si se han agregado sumo los bytes donde correspondan.
# * El problema es que por cada par de ips de origen que cargo, tengo que compararlas con TODAS las filas del df de destino agregadas hasta el momento, lo que no escala muy bien.
# * Ademas capaz hay alguna forma más eficiente de hacer esa comparación de ips

# %%
df3=df2[0:1].copy()             #Crea el df definitivo 
for x in df2.index:
    if(x==0):
        continue #No chequeo primer valor que ya guardé al inicializar
    flag=False   #Indica si coincidió con algun par ya agregado o debo agregarlo al df definiivo
    for y in df3.index:
        if df2.iloc[x][0]==df3.iloc[y][0] and df2.iloc[x][1]==df3.iloc[y][1]: #src1==src2 y dst1==dst2
            df3["SrcBytes"][y]=df3.iloc[y][2].copy()+df2.iloc[x][2].copy()
            df3["DstBytes"][y]=df3.iloc[y][3].copy()+df2.iloc[x][3].copy()
            flag=True
            break
        elif df2.iloc[x][0]==df3.iloc[y][1] and df2.iloc[x][1]==df3.iloc[y][0]: #src1==dst2 y dst1==src2 coincidentes
            df3["SrcBytes"][y]=df3.iloc[y][2].copy()+df2.iloc[x][3].copy()
            df3["DstBytes"][y]=df3.iloc[y][3].copy()+df2.iloc[x][2].copy()
            flag=True
            break
    if flag==False:
        df3=df3.append(df2.iloc[x].copy(), ignore_index = True)
    if(x%100==0):
        print(x)
    if(x%1000==0):
        break

print(df3)
# Out:
# <ipython-input-65-816ab96b3f41>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["SrcBytes"][y]=df3.iloc[y][2].copy()+df2.iloc[x][3].copy()
# <ipython-input-65-816ab96b3f41>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["DstBytes"][y]=df3.iloc[y][3].copy()+df2.iloc[x][2].copy()
# <ipython-input-65-816ab96b3f41>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %% [markdown]
# ## Intento 2 (107 años)

# %% [markdown]
# * Acá la idea es ir sobreescribiendo el df original y quitando filas, para que los próximos ejemplos tengan que comparar cada vez menos. Así toma el primer par de ips y busca en todo el df los que coincidan, para combinarlos y quitarlos. Luego sigue con el segundo par y así.
# * Dada la cantidad de nodos distintos según el paper no parece probable que reduzca mucho esas búsquedas
# * Está fallando porque df3.index no se achica cuando quito ejemplos. No lo corregí porque de por sí la solución tarda mucho y esto no cambia eso.

# %%
df3=df2.copy()
print(df3)
# Out:
#                SrcAddr        DstAddr  SrcBytes  DstBytes
# 0        212.50.71.179  147.32.84.229       413       462
# 1        84.13.246.132  147.32.84.229        75        60
# 2        217.163.21.35  147.32.86.194        60        60
# 3           83.3.77.74    147.32.85.5       120        60
# 4        74.89.223.204  147.32.84.229      1596      1260
# ...                ...            ...       ...       ...
# 2824631   147.32.86.92    147.32.80.9        79       129
# 2824632   58.165.41.84  147.32.84.229        75       464
# 2824633  147.32.84.171  78.191.168.43        74         0
# 2824634    93.79.39.15  147.32.84.229       460        60
# 2824635  78.56.231.126  147.32.84.229        77        60
#
# [2824636 rows x 4 columns]

# %%
for x in df3.index:   
    for y in df3.index:  #Esto se achica si dentro del bucle borro elementos? NO SE ACHICA. OJO CORREGIR PORQUE FALLA
        if df3.iloc[x][0]==df3.iloc[y][0] and df3.iloc[x][1]==df3.iloc[y][1]:
            df3["SrcBytes"][x]=df3.iloc[y][2].copy()+df3.iloc[x][2].copy()
            df3["DstBytes"][x]=df3.iloc[y][3].copy()+df3.iloc[x][3].copy()
            df3=df3.drop(df3.index[y])
        elif df3.iloc[x][0]==df3.iloc[y][1] and df3.iloc[x][1]==df3.iloc[y][0]:
            df3["SrcBytes"][y]=df3.iloc[y][2].copy()+df3.iloc[x][3].copy()
            df3["DstBytes"][y]=df3.iloc[y][3].copy()+df3.iloc[x][2].copy()
            df3=df3.drop(df3.index[y])
        if(y%10000==0):
            print(y)
    break
    

print(df3)
# Out:
# <ipython-input-94-a75e81598f5f>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["SrcBytes"][x]=df3.iloc[y][2].copy()+df3.iloc[x][2].copy()
# <ipython-input-94-a75e81598f5f>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["DstBytes"][x]=df3.iloc[y][3].copy()+df3.iloc[x][3].copy()
# 0
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 230000
# 240000
# 250000
# 260000
# 270000
# 280000
# 290000
# 300000
# 310000
# 320000
# 330000
# 340000
# 350000
# 360000
# ...

# %% [markdown]
# ## Intento 3

# %% [markdown]
# Aún no lo codeo pero la idea sería:
# * Ordenar cada par de ips en su fila con src la menor y dst la mayor cambiando bytes si corresponde
# * Ordenar las filas de menor a mayor src ip
# * Hacer la comparación de cada par de ips solo con las que comparten su src ip (ahí son muchisimas menos comparaciones, salvo que muchas compartan un mismo src ip).
#
# Problema:
# * Creo que hay ips con nombres feos que no son numeros separados por puntos, asi que no se me ocurre como dar un orden "ascendente"

# %%
#Juntar src y dst address en una string para comparar mas rapido. Invertir ips menor y luego mayor y sus src y dst bytes correspondientes
